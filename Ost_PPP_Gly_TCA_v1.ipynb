# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#SBML-FULL-model-ostreococcus" data-toc-modified-id="SBML-FULL-model-ostreococcus-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SBML FULL model ostreococcus</a></div><div class="lev1 toc-item"><a href="#Otauri-Models-from-Pathway-tools" data-toc-modified-id="Otauri-Models-from-Pathway-tools-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Otauri Models from Pathway tools</a></div><div class="lev2 toc-item"><a href="#conversion-from-SBML-to-Boltzmann-input-files" data-toc-modified-id="conversion-from-SBML-to-Boltzmann-input-files-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>conversion from SBML to Boltzmann input files</a></div><div class="lev2 toc-item"><a href="#Centeral-Metabolism-Rxn-for-MetaFlux-in-PT" data-toc-modified-id="Centeral-Metabolism-Rxn-for-MetaFlux-in-PT-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Centeral Metabolism Rxn for MetaFlux in PT</a></div><div class="lev2 toc-item"><a href="#Get-Chemical-Potential" data-toc-modified-id="Get-Chemical-Potential-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Get Chemical Potential</a></div><div class="lev1 toc-item"><a href="#Boltzmann" data-toc-modified-id="Boltzmann-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Boltzmann</a></div><div class="lev2 toc-item"><a href="#Analyze-Simulation-Results-for-centeral-Metabolism" data-toc-modified-id="Analyze-Simulation-Results-for-centeral-Metabolism-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Analyze Simulation Results for centeral Metabolism</a></div><div class="lev3 toc-item"><a href="#Derivatives-from-ODE-thermodynamic-optimization-simulation" data-toc-modified-id="Derivatives-from-ODE-thermodynamic-optimization-simulation-311"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Derivatives from ODE thermodynamic optimization simulation</a></div><div class="lev3 toc-item"><a href="#Likelihoods-from-Deterministic-Simulation" data-toc-modified-id="Likelihoods-from-Deterministic-Simulation-312"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Likelihoods from Deterministic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Deterministic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Deterministic-Simulation-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Analyze Metabolite Levels from Deterministic Simulation</a></div><div class="lev2 toc-item"><a href="#Likelihoods-from-Stochastic-Simulation" data-toc-modified-id="Likelihoods-from-Stochastic-Simulation-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Likelihoods from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Read-in-Flux-Values-from-Stochastic-Simulation" data-toc-modified-id="Read-in-Flux-Values-from-Stochastic-Simulation-34"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Read in Flux Values from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Analyze-Metabolite-Levels-from-Stochastic-Simulation" data-toc-modified-id="Analyze-Metabolite-Levels-from-Stochastic-Simulation-35"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Analyze Metabolite Levels from Stochastic Simulation</a></div><div class="lev2 toc-item"><a href="#Compare-ODE-and-Stochastic-Metabolite-Concentrations" data-toc-modified-id="Compare-ODE-and-Stochastic-Metabolite-Concentrations-36"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Compare ODE and Stochastic Metabolite Concentrations</a></div><div class="lev2 toc-item"><a href="#Display-Pathway-Predictions" data-toc-modified-id="Display-Pathway-Predictions-37"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Display Pathway Predictions</a></div><div class="lev2 toc-item"><a href="#Power-and-Fluxes" data-toc-modified-id="Power-and-Fluxes-38"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Power and Fluxes</a></div><div class="lev1 toc-item"><a href="#Boltzmann-to-sbml-file-for-biocyc" data-toc-modified-id="Boltzmann-to-sbml-file-for-biocyc-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Boltzmann to sbml file for biocyc</a></div>

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import subprocess
import re
import os
import mentos
from IPython.core.display import display
#from ipynb_latex_setup import *
# %matplotlib inline
import cobra
#%matplotlib pdf
#matplotlib.matplotlib_fname()
#import matplotlib.rcsetup as rcsetup
#print(rcsetup.all_backends)

# %% [markdown]
# # SBML FULL model ostreococcus

# %%
import json
import os
import cobra
modeldir = '/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML'
full_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Libourel_Otauri_SBMLModel.xml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'Otauri.COBRA-sbml3.xml'))
full_model.optimize()
# Out:
# ----------------------------------------------------------------------
# UnicodeEncodeError                   Traceback (most recent call last)
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/solution.pyc in _repr_html_(self)
#      94                         'value {:.3f}</strong><br>{}'
#      95                         .format(self.objective_value,
# ---> 96                                 self.to_frame()._repr_html_()))
#      97         else:
#      98             html = '<strong><em>{}</em> solution</strong>'.format(self.status)
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xd7' in position 1375: ordinal not in range(128)
# <Solution 0.275 at 0x1215dcdd0>

# %% [markdown]
# #  Otauri Models from Pathway tools

# %%
import json
import os
import cobra
modeldir = './'
core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'PPP_Gly_TCA_A-COA-Bys.sbml'))
#core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST_COBRA_sbml3.xml'))
core_model.objective= 'RXN__45__1641'
core_model.optimize()
#core_model.metabolites.Triacylglycerols_c
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-34-c9c1bcb68958> in <module>()
#       5 core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'PPP_Gly_TCA_A-COA-Bys.sbml'))
#       6 #core_model = cobra.io.read_sbml_model(os.path.join(modeldir, 'central_metabolism_ST_COBRA_sbml3.xml'))
# ----> 7 core_model.objective= 'RXN__45__1641'
#       8 core_model.optimize()
#       9 #core_model.metabolites.Triacylglycerols_c
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/cobra/core/model.pyc in objective(self, value)
#     900                 reactions = self.reactions.get_by_any(value)
#     901             except KeyError:
# --> 902                 raise ValueError('invalid objective')
#     903             value = {rxn: 1 for rxn in reactions}
#     904         set_objective(self, value, additive=False)
#
# ValueError: invalid objective

# %% [markdown]
# ## conversion from SBML to Boltzmann input files

# %%
import libsbml
r = libsbml.SBMLReader()
d = r.readSBML('modeldir/')
if d.getNumErrors() > 0 :
    print (d.getError(0).getMessage())
else : 
    m = d.getModel()
deltag = pd.read_table('/Users/kuma889/Projects/Boltzmann/Boltz/Ostreococcus/SBML/central_metabolism_dg0.tab', index_col='ID')
deltag
# Out:
# File unreadable.
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Gibbs-0  Unnamed: 4
# ID
# FUMHYDR-RXN                                 0.613         nan
# MALATE-DEH-RXN                               4.46         nan
# 2OXOGLUTARATEDEH-RXN                        -11.4         nan
# ACONITATEHYDR-RXN                           -3.13         nan
# CITSYN-RXN                                  -10.5         nan
# ACONITATEDEHYDR-RXN                          3.35         nan
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN            1.62         nan
# SUCCCOASYN-RXN                              -1.05         nan
# RXN-14971                                    22.8         nan
# RXN0-1132                                    19.4         nan
# RXN0-1133                                   -20.5         nan
# RXN0-1134                                   -49.9         nan
# PSII-RXN                                      nan         nan
# 1.18.1.2-RXN                                 9.63         nan
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN      nan         nan
# RXN-15479                                     nan         nan
# TRANSALDOL-RXN                              -2.92         nan
# 6PGLUCONOLACT-RXN                           -7.36         nan
# RXN-9952                                    -1.38         nan
# GLU6PDEHYDROG-RXN                           -5.93         nan
# 3PGAREARR-RXN                               -1.32         nan
# 2PGADEHYDRAT-RXN                           -0.187         nan
# PEPDEPHOS-RXN                               -2.23         nan
# RXN-15513                                   -1.32         nan
# 6PFRUCTPHOS-RXN                             -14.5         nan
# PGLUCISOM-RXN                                1.38         nan
# GAPOXNPHOSPHN-RXN                           -15.2         nan
# PEPSYNTH-RXN                                -9.58         nan
# 1.1.1.8-RXN                                  4.15         nan
# RXN-15745                                    12.5         nan
# RXN-12383                                       0         nan
# PHOSPHATIDATE-PHOSPHATASE-RXN               -3.05         nan
# RXN-1381                                      253         nan
# RXN-1623                                      325         nan
# RXN-1641                                        0         nan
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN          325         nan
# RXN-12959                                   -99.5         nan
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN        4.14         nan
# PHOSPHORIBULOKINASE-RXN                     -17.3         nan
# 2TRANSKETO-RXN                               3.96         nan
# RIB5PISOM-RXN                               -6.13         nan
# RIBULP3EPIM-RXN                                 0         nan
# 1TRANSKETO-RXN                               1.23         nan
# PHOSGLYPHOS-RXN                             -7.51         nan
# TRIOSEPISOMERIZATION-RXN                    -1.83         nan
# F16ALDOLASE-RXN                              8.23         nan
# F16BDEPHOS-RXN                               6.89         nan
# 1.2.1.13-RXN                                -16.4         nan
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN             9.71         nan
# SEDOBISALDOL-RXN                            -8.13         nan

# %%
import re
class sbml2boltzmann:
    def __init__( self, sbml, deltag ):
        self.sbml = sbml
        self.deltag = deltag['Gibbs-0'].to_dict()
        self.ordRE = re.compile('__([0-9]+)__')
    def repl( self, matchobj ):
        return chr(int(matchobj.group(1)))
   
    def unmunge( self, sbmlid ):
        return self.ordRE.sub( self.repl, sbmlid)
   
    def get_met_comp( self, speciesId ):
        s = self.sbml.getSpecies(speciesId)
        if s.getCompartment() == 'CCO__45__CYTOSOL':
            return self.unmunge( s.getId() + ':' + s.getCompartment() )
        else:
            return self.unmunge( s.getId()).replace('[',':').rstrip(']')
       
    def write_compartment( self, filename ):
        with open(filename, 'w') as out:
            i = 1
            for comp in self.sbml.getListOfCompartments():
                out.write('{}\t{}\tliters\t0\tV\n'.format(self.unmunge(comp.getId()), float(i)))
                i +=1
    def write_concentrations( self, filename, volume=1.0e-15, conc_units=1.0e-9, default_conc=1.1111111e-01):
        with open(filename, 'w') as out:
            out.write('VOLUME\t{}\n'.format(volume))
            out.write('CONC_UNITS\t{}\n'.format(conc_units))
            for species in self.sbml.getListOfSpecies():
                if species.getBoundaryCondition():
                    boundary="F"
                else :
                    boundary="V"
                out.write('{}\t{}\t{}\n'.format(self.get_met_comp(species.getId()), default_conc, boundary))
   
    def getDeltaG( self, rxnName ):
        if rxnName in self.deltag:
            return self.deltag[rxnName]
        else:
            return 0.0
    def write_reactions( self, filename):
        with open(filename, 'w') as out:
            for rxn in self.sbml.getListOfReactions():
                out.write('REACTION\t{}\n'.format(rxn.getName()))
                out.write('LEFT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfReactants()])))
                out.write('RIGHT\t{}\n'.format(' + '.join([self.get_met_comp(sr.getSpecies()) 
                                                         for sr in rxn.getListOfProducts()])))
                out.write('DGZERO\t{}\n'.format(self.getDeltaG(rxn.getName())))
                out.write('DGZERO_UNITS\t{}\n'.format('KCAL/MOL'))
                out.write('//\n')
                         
s2b = sbml2boltzmann(m, deltag)
s2b.get_met_comp('M_CPD__45__548')
s2b.write_compartment('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_test.cmpts')
s2b.write_concentrations('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_testt.in')
s2b.write_reactions('/Users/kuma889/Projects/Ostreococcus/SBML/central_metabolism_dg0_rxns.dat')

# %% [markdown]
# ## Centeral Metabolism Rxn for MetaFlux in PT

# %%
import pandas as pd
cm=pd.read_table(os.path.join(modeldir, "central_metabolism_st.tab"), index_col="ID")
cm
with open(os.path.join(modeldir,"central_metabolism.rxn"), "w") as out:
    out.write('\n'.join(cm.index))
cm
# Out:
#                                                                                        Name  \
# ID
# FUMHYDR-RXN                               (<i>S</i>)-malate  &larr;  fumarate + H<sub>2<...
# MALATE-DEH-RXN                            (<i>S</i>)-malate + NAD<sup>+</sup>  &harr;  o...
# 2OXOGLUTARATEDEH-RXN                      2-oxoglutarate + coenzyme A + NAD<sup>+</sup> ...
# ACONITATEHYDR-RXN                         <i>cis</i>-aconitate + H<sub>2</sub>O  &harr; ...
# CITSYN-RXN                                acetyl-CoA + oxaloacetate + H<sub>2</sub>O  &r...
# ACONITATEDEHYDR-RXN                       citrate  &harr;  <i>cis</i>-aconitate + H<sub>...
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN         D-<i>threo</i>-isocitrate + NAD<sup>+</sup>  &...
# SUCCCOASYN-RXN                            succinate + ATP + coenzyme A  &harr;  succinyl...
# RXN-14971                                 succinate<SUB>[in]</SUB> + an electron-transfe...
# RXN0-1132                                 a [pyruvate dehydrogenase E2 protein] <i>N<sup...
# RXN0-1133                                 acetyl-CoA + a [pyruvate dehydrogenase E2 prot...
# RXN0-1134                                 pyruvate + a [pyruvate dehydrogenase E2 protei...
# PSII-RXN                                  2 a plastoquinol<SUB>[membrane]</SUB> + 4 H<SU...
# 1.18.1.2-RXN                              2 a reduced ferredoxin [iron-sulfur] cluster<S...
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN  2 an oxidized plastocyanin<SUB>[in]</SUB> + a ...
# RXN-15479                                 an oxidized plastocyanin<SUB>[in]</SUB> + a re...
# TRANSALDOL-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# 6PGLUCONOLACT-RXN                         6-phospho D-glucono-1,5-lactone + H<sub>2</sub...
# RXN-9952                                  D-gluconate 6-phosphate + NADP<sup>+</sup>  &r...
# GLU6PDEHYDROG-RXN                         D-glucopyranose 6-phosphate + NADP<sup>+</sup>...
# 3PGAREARR-RXN                             2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 2PGADEHYDRAT-RXN                          2-phospho-D-glycerate  &harr;  phospho<i>enol<...
# PEPDEPHOS-RXN                             pyruvate + ATP  &larr;  phospho<i>enol</i>pyru...
# RXN-15513                                 2-phospho-D-glycerate  &harr;  3-phospho-D-gly...
# 6PFRUCTPHOS-RXN                           ATP + &beta;-D-fructofuranose 6-phosphate  &ra...
# PGLUCISOM-RXN                             D-glucopyranose 6-phosphate  &harr;  &beta;-D-...
# GAPOXNPHOSPHN-RXN                         D-glyceraldehyde 3-phosphate + NAD<sup>+</sup>...
# PEPSYNTH-RXN                              pyruvate + ATP + H<sub>2</sub>O  &rarr;  phosp...
# 1.1.1.8-RXN                               <i>sn</i>-glycerol 3-phosphate + NAD<sup>+</su...
# RXN-15745                                 <i>sn</i>-glycerol 3-phosphate<SUB>[in]</SUB> ...
# RXN-12383                                 2 a 1,2-diacyl-<i>sn</i>-glycerol  &harr;  a t...
# PHOSPHATIDATE-PHOSPHATASE-RXN             a 1,2-diacyl-<i>sn</i>-glycerol 3-phosphate + ...
# RXN-1381                                  a long-chain acyl-CoA + <i>sn</i>-glycerol 3-p...
# RXN-1623                                  a long-chain acyl-CoA + a 1-acyl-<i>sn</i>-gly...
# RXN-1641                                  a phosphatidylcholine + a 1,2-diacyl-<i>sn</i>...
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN      an acyl-CoA + a 1,2-diacyl-<i>sn</i>-glycerol ...
# RXN-12959                                 CTP + a 1,2-diacyl-<i>sn</i>-glycerol  &rarr; ...
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN     2 3-phospho-D-glycerate + 2 H<SUP>+</SUP>  &la...
# PHOSPHORIBULOKINASE-RXN                   D-ribulose 5-phosphate + ATP  &rarr;  D-ribulo...
# 2TRANSKETO-RXN                            D-erythrose 4-phosphate + D-xylulose 5-phospha...
# RIB5PISOM-RXN                             D-ribose 5-phosphate  &harr;  D-ribulose 5-pho...
# RIBULP3EPIM-RXN                           D-ribulose 5-phosphate  &harr;  D-xylulose 5-p...
# 1TRANSKETO-RXN                            D-sedoheptulose 7-phosphate + D-glyceraldehyde...
# PHOSGLYPHOS-RXN                           3-phospho-D-glycerate + ATP  &harr;  3-phospho...
# TRIOSEPISOMERIZATION-RXN                  D-glyceraldehyde 3-phosphate  &harr;  glyceron...
# F16ALDOLASE-RXN                           fructose 1,6-bisphosphate  &harr;  glycerone p...
# F16BDEPHOS-RXN                            fructose 1,6-bisphosphate + H<sub>2</sub>O  &r...
# 1.2.1.13-RXN                              D-glyceraldehyde 3-phosphate + NADP<sup>+</sup...
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN          D-sedoheptulose-1,7-bisphosphate + H<sub>2</su...
# SEDOBISALDOL-RXN                          glycerone phosphate + D-erythrose 4-phosphate ...
#
#                                                                       Matches  \
# ID
# FUMHYDR-RXN                                                          PWY-5690
# MALATE-DEH-RXN                                                       PWY-5690
# 2OXOGLUTARATEDEH-RXN                                                 PWY-5690
# ACONITATEHYDR-RXN                                                    PWY-5690
# CITSYN-RXN                                                           PWY-5690
# ACONITATEDEHYDR-RXN                                                  PWY-5690
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                                    PWY-5690
# SUCCCOASYN-RXN                                                       PWY-5690
# RXN-14971                                                            PWY-5690
# RXN0-1132                                                      PYRUVDEHYD-PWY
# RXN0-1133                                                      PYRUVDEHYD-PWY
# RXN0-1134                                                      PYRUVDEHYD-PWY
# PSII-RXN                                                              PWY-101
# 1.18.1.2-RXN                                                          PWY-101
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN                              PWY-101
# RXN-15479                                                             PWY-101
# TRANSALDOL-RXN                                        PENTOSE-P-PWY, PWY-5723
# 6PGLUCONOLACT-RXN                                               PENTOSE-P-PWY
# RXN-9952                                                        PENTOSE-P-PWY
# GLU6PDEHYDROG-RXN                                               PENTOSE-P-PWY
# 3PGAREARR-RXN                                            GLYCOLYSIS, PWY-5723
# 2PGADEHYDRAT-RXN                                         GLYCOLYSIS, PWY-5723
# PEPDEPHOS-RXN                                            GLYCOLYSIS, PWY-5723
# RXN-15513                                                          GLYCOLYSIS
# 6PFRUCTPHOS-RXN                                                    GLYCOLYSIS
# PGLUCISOM-RXN                                                      GLYCOLYSIS
# GAPOXNPHOSPHN-RXN                                                  GLYCOLYSIS
# PEPSYNTH-RXN                                                       GLYCOLYSIS
# 1.1.1.8-RXN                                                          PWY-6118
# RXN-15745                                                            PWY-6118
# RXN-12383                                                        TRIGLSYN-PWY
# PHOSPHATIDATE-PHOSPHATASE-RXN                                    TRIGLSYN-PWY
# RXN-1381                                                         TRIGLSYN-PWY
# RXN-1623                                                         TRIGLSYN-PWY
# RXN-1641                                                         TRIGLSYN-PWY
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN                             TRIGLSYN-PWY
# RXN-12959                                                        TRIGLSYN-PWY
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN                    CALVIN-PWY, PWY-5723
# PHOSPHORIBULOKINASE-RXN                                  CALVIN-PWY, PWY-5723
# 2TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIB5PISOM-RXN                             CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# RIBULP3EPIM-RXN                           CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# 1TRANSKETO-RXN                            CALVIN-PWY, PENTOSE-P-PWY, PWY-5723
# PHOSGLYPHOS-RXN                                        CALVIN-PWY, GLYCOLYSIS
# TRIOSEPISOMERIZATION-RXN                               CALVIN-PWY, GLYCOLYSIS
# F16ALDOLASE-RXN                                        CALVIN-PWY, GLYCOLYSIS
# F16BDEPHOS-RXN                                         CALVIN-PWY, GLYCOLYSIS
# 1.2.1.13-RXN                                                       CALVIN-PWY
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                                   CALVIN-PWY
# SEDOBISALDOL-RXN                                                   CALVIN-PWY
#
#                                           Unnamed: 3
# ID
# FUMHYDR-RXN                                      NaN
# MALATE-DEH-RXN                                   NaN
# 2OXOGLUTARATEDEH-RXN                             NaN
# ACONITATEHYDR-RXN                                NaN
# CITSYN-RXN                                       NaN
# ACONITATEDEHYDR-RXN                              NaN
# ISOCITRATE-DEHYDROGENASE-NAD+-RXN                NaN
# SUCCCOASYN-RXN                                   NaN
# RXN-14971                                        NaN
# RXN0-1132                                        NaN
# RXN0-1133                                        NaN
# RXN0-1134                                        NaN
# PSII-RXN                                         NaN
# 1.18.1.2-RXN                                     NaN
# PLASTOQUINOL--PLASTOCYANIN-REDUCTASE-RXN         NaN
# RXN-15479                                        NaN
# TRANSALDOL-RXN                                   NaN
# 6PGLUCONOLACT-RXN                                NaN
# RXN-9952                                         NaN
# GLU6PDEHYDROG-RXN                                NaN
# 3PGAREARR-RXN                                    NaN
# 2PGADEHYDRAT-RXN                                 NaN
# PEPDEPHOS-RXN                                    NaN
# RXN-15513                                        NaN
# 6PFRUCTPHOS-RXN                                  NaN
# PGLUCISOM-RXN                                    NaN
# GAPOXNPHOSPHN-RXN                                NaN
# PEPSYNTH-RXN                                     NaN
# 1.1.1.8-RXN                                      NaN
# RXN-15745                                        NaN
# RXN-12383                                        NaN
# PHOSPHATIDATE-PHOSPHATASE-RXN                    NaN
# RXN-1381                                         NaN
# RXN-1623                                         NaN
# RXN-1641                                         NaN
# DIACYLGLYCEROL-O-ACYLTRANSFERASE-RXN             NaN
# RXN-12959                                        NaN
# RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN            NaN
# PHOSPHORIBULOKINASE-RXN                          NaN
# 2TRANSKETO-RXN                                   NaN
# RIB5PISOM-RXN                                    NaN
# RIBULP3EPIM-RXN                                  NaN
# 1TRANSKETO-RXN                                   NaN
# PHOSGLYPHOS-RXN                                  NaN
# TRIOSEPISOMERIZATION-RXN                         NaN
# F16ALDOLASE-RXN                                  NaN
# F16BDEPHOS-RXN                                   NaN
# 1.2.1.13-RXN                                     NaN
# SEDOHEPTULOSE-BISPHOSPHATASE-RXN                 NaN
# SEDOBISALDOL-RXN                                 NaN

# %% [markdown]
# ## Get Chemical Potential

# %%
import pandas as pd
from IPython.display import HTML
import libsbml
#r = str(to_unicode(
#            to_bytes(
#                requests.get('http://bigg.ucsd.edu/static/models/iJO1366.xml').text,
#                'ascii','ignore')))


#d = libsbml.SBMLReader().readSBMLFromString(r)
d = libsbml.SBMLReader().readSBML('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
iJO1366_sbml= d.getModel()
iJO1366 = cobra.io.read_sbml_model('/Users/kuma889/Projects/Boltzmann/MENTOS/Core/iJO1366.xml')
online_supp = 'http://onlinelibrary.wiley.com/store/10.1038/msb4100155/asset/supinfo/msb4100155-sup-0003.xls?v=1&s=d6fe37a9ffd941ef5bc27013b9fa8868482e2d19'
local_supp = '/Users/kuma889/Projects/Boltzmann/MENTOS/Core/msb4100155-sup-0003.xls'
metG = pd.read_excel(local_supp, 
                     sheetname='compounds').rename(columns=lambda x: x.strip()).set_index('abbreviation')
metG.index = metG.index.str.replace('-','__').str.replace('__C','_C')
ijomets = [m.id for m in iJO1366.metabolites]
umets = pd.DataFrame({'universal_BiGG':[m.id[:-2] for m in iJO1366.metabolites]},index=ijomets)
mu0 = umets.join(other=metG, on='universal_BiGG')['formation delta G (pH 7)' ].replace('Not calculated',np.nan).dropna()
print(len(mu0))
display(HTML(mu0.to_frame().to_html()))

idx = fullS.index.intersection(mu0.index)

deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
deltaG0.to_frame()
# Out:
# 1436
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>formation delta G (pH 7)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10fthf_c</th>
#       <td>-144.2810</td>
#     </tr>
#     <tr>
#       <th>12dgr120_c</th>
#       <td>-157.8860</td>
#     </tr>
#     <tr>
#       <th>12dgr140_c</th>
#       <td>-151.3050</td>
#     </tr>
#     <tr>
#       <th>12dgr141_c</th>
#       <td>-106.6220</td>
#     </tr>
#     <tr>
#       <th>12dgr160_c</th>
#       <td>-144.7230</td>
#     </tr>
#     <tr>
#       <th>12dgr161_c</th>
#       <td>-100.0410</td>
#     </tr>
#     <tr>
#       <th>12dgr180_c</th>
#       <td>-138.1420</td>
#     </tr>
#     <tr>
#       <th>12dgr181_c</th>
#       <td>-93.4598</td>
#     </tr>
#     <tr>
#       <th>12ppd__R_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>12ppd__S_c</th>
#       <td>-79.6929</td>
#     </tr>
#     <tr>
#       <th>13dpg_c</th>
#       <td>-585.8110</td>
#     </tr>
#     <tr>
#       <th>14glucan_c</th>
#       <td>-1006.5000</td>
#     </tr>
#     <tr>
#       <th>15dap_c</th>
#       <td>-4.4171</td>
#     </tr>
#     <tr>
#       <th>1ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>1hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>1hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>1odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>1odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>1pyr5c_c</th>
#       <td>-60.2665</td>
#     </tr>
#     <tr>
#       <th>1tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>1tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>23dappa_c</th>
#       <td>-89.0161</td>
#     </tr>
#     <tr>
#       <th>23ddhb_c</th>
#       <td>-126.7850</td>
#     </tr>
#     <tr>
#       <th>23dhb_c</th>
#       <td>-131.6250</td>
#     </tr>
#     <tr>
#       <th>23dhba_c</th>
#       <td>-335.8130</td>
#     </tr>
#     <tr>
#       <th>23dhbzs_c</th>
#       <td>-198.7250</td>
#     </tr>
#     <tr>
#       <th>23dhdp_c</th>
#       <td>-134.6010</td>
#     </tr>
#     <tr>
#       <th>23dhmb_c</th>
#       <td>-160.7870</td>
#     </tr>
#     <tr>
#       <th>23dhmp_c</th>
#       <td>-159.1420</td>
#     </tr>
#     <tr>
#       <th>23doguln_c</th>
#       <td>-247.1760</td>
#     </tr>
#     <tr>
#       <th>25aics_c</th>
#       <td>-486.8860</td>
#     </tr>
#     <tr>
#       <th>25dkglcn_c</th>
#       <td>-249.6670</td>
#     </tr>
#     <tr>
#       <th>25drapp_c</th>
#       <td>-326.1570</td>
#     </tr>
#     <tr>
#       <th>26dap__LL_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>26dap__M_c</th>
#       <td>-163.7430</td>
#     </tr>
#     <tr>
#       <th>2agpe120_c</th>
#       <td>-331.8970</td>
#     </tr>
#     <tr>
#       <th>2agpe140_c</th>
#       <td>-328.6060</td>
#     </tr>
#     <tr>
#       <th>2agpe141_c</th>
#       <td>-306.2650</td>
#     </tr>
#     <tr>
#       <th>2agpe160_c</th>
#       <td>-325.3160</td>
#     </tr>
#     <tr>
#       <th>2agpe161_c</th>
#       <td>-302.9740</td>
#     </tr>
#     <tr>
#       <th>2agpe180_c</th>
#       <td>-322.0250</td>
#     </tr>
#     <tr>
#       <th>2agpe181_c</th>
#       <td>-299.6840</td>
#     </tr>
#     <tr>
#       <th>2agpg120_c</th>
#       <td>-403.3110</td>
#     </tr>
#     <tr>
#       <th>2agpg140_c</th>
#       <td>-400.0200</td>
#     </tr>
#     <tr>
#       <th>2agpg141_c</th>
#       <td>-377.6790</td>
#     </tr>
#     <tr>
#       <th>2agpg160_c</th>
#       <td>-396.7300</td>
#     </tr>
#     <tr>
#       <th>2agpg161_c</th>
#       <td>-374.3880</td>
#     </tr>
#     <tr>
#       <th>2agpg180_c</th>
#       <td>-393.4390</td>
#     </tr>
#     <tr>
#       <th>2agpg181_c</th>
#       <td>-371.0980</td>
#     </tr>
#     <tr>
#       <th>2ahbut_c</th>
#       <td>-151.1490</td>
#     </tr>
#     <tr>
#       <th>2amsa_c</th>
#       <td>-114.7020</td>
#     </tr>
#     <tr>
#       <th>2aobut_c</th>
#       <td>-116.2480</td>
#     </tr>
#     <tr>
#       <th>2cpr5p_c</th>
#       <td>-391.5870</td>
#     </tr>
#     <tr>
#       <th>2dda7p_c</th>
#       <td>-467.9060</td>
#     </tr>
#     <tr>
#       <th>2ddecg3p_c</th>
#       <td>-348.7750</td>
#     </tr>
#     <tr>
#       <th>2ddg6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2ddglcn_c</th>
#       <td>-222.2060</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal_c</th>
#       <td>-219.7150</td>
#     </tr>
#     <tr>
#       <th>2dh3dgal6p_c</th>
#       <td>-431.6070</td>
#     </tr>
#     <tr>
#       <th>2dhguln_c</th>
#       <td>-257.6600</td>
#     </tr>
#     <tr>
#       <th>2dhp_c</th>
#       <td>-148.6590</td>
#     </tr>
#     <tr>
#       <th>2dmmq8_c</th>
#       <td>208.4720</td>
#     </tr>
#     <tr>
#       <th>2dmmql8_c</th>
#       <td>184.0690</td>
#     </tr>
#     <tr>
#       <th>2dr1p_c</th>
#       <td>-352.9020</td>
#     </tr>
#     <tr>
#       <th>2dr5p_c</th>
#       <td>-352.9030</td>
#     </tr>
#     <tr>
#       <th>2h3oppan_c</th>
#       <td>-149.8170</td>
#     </tr>
#     <tr>
#       <th>2hdec9eg3p_c</th>
#       <td>-319.8530</td>
#     </tr>
#     <tr>
#       <th>2hdecg3p_c</th>
#       <td>-342.1940</td>
#     </tr>
#     <tr>
#       <th>2ippm_c</th>
#       <td>-142.6780</td>
#     </tr>
#     <tr>
#       <th>2mahmp_c</th>
#       <td>-412.4040</td>
#     </tr>
#     <tr>
#       <th>2mcacn_c</th>
#       <td>-222.6120</td>
#     </tr>
#     <tr>
#       <th>2mcit_c</th>
#       <td>-280.4140</td>
#     </tr>
#     <tr>
#       <th>2me4p_c</th>
#       <td>-365.5040</td>
#     </tr>
#     <tr>
#       <th>2obut_c</th>
#       <td>-110.9280</td>
#     </tr>
#     <tr>
#       <th>2odec11eg3p_c</th>
#       <td>-316.5620</td>
#     </tr>
#     <tr>
#       <th>2odecg3p_c</th>
#       <td>-338.9040</td>
#     </tr>
#     <tr>
#       <th>2ohph_c</th>
#       <td>175.2550</td>
#     </tr>
#     <tr>
#       <th>2ombzl_c</th>
#       <td>150.7870</td>
#     </tr>
#     <tr>
#       <th>2omhmbl_c</th>
#       <td>109.7890</td>
#     </tr>
#     <tr>
#       <th>2ommbl_c</th>
#       <td>149.2050</td>
#     </tr>
#     <tr>
#       <th>2omph_c</th>
#       <td>190.2020</td>
#     </tr>
#     <tr>
#       <th>2oph_c</th>
#       <td>214.6710</td>
#     </tr>
#     <tr>
#       <th>2p4c2me_c</th>
#       <td>-856.9750</td>
#     </tr>
#     <tr>
#       <th>2pg_c</th>
#       <td>-371.1370</td>
#     </tr>
#     <tr>
#       <th>2pglyc_c</th>
#       <td>-334.8390</td>
#     </tr>
#     <tr>
#       <th>2shchc_c</th>
#       <td>-193.5190</td>
#     </tr>
#     <tr>
#       <th>2tdec7eg3p_c</th>
#       <td>-323.1440</td>
#     </tr>
#     <tr>
#       <th>2tdecg3p_c</th>
#       <td>-345.4850</td>
#     </tr>
#     <tr>
#       <th>2tpr3dpcoa_c</th>
#       <td>-1297.0800</td>
#     </tr>
#     <tr>
#       <th>34hpp_c</th>
#       <td>-114.8580</td>
#     </tr>
#     <tr>
#       <th>3c2hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c3hmp_c</th>
#       <td>-199.5390</td>
#     </tr>
#     <tr>
#       <th>3c4mop_c</th>
#       <td>-189.0560</td>
#     </tr>
#     <tr>
#       <th>3dhguln_c</th>
#       <td>-260.1500</td>
#     </tr>
#     <tr>
#       <th>3dhgulnp_c</th>
#       <td>-472.0420</td>
#     </tr>
#     <tr>
#       <th>3dhq_c</th>
#       <td>-215.0630</td>
#     </tr>
#     <tr>
#       <th>3dhsk_c</th>
#       <td>-166.8340</td>
#     </tr>
#     <tr>
#       <th>3hbcoa_c</th>
#       <td>-819.2920</td>
#     </tr>
#     <tr>
#       <th>3hcinnm_c</th>
#       <td>-71.3229</td>
#     </tr>
#     <tr>
#       <th>3hdcoa_c</th>
#       <td>-809.4210</td>
#     </tr>
#     <tr>
#       <th>3hddcoa_c</th>
#       <td>-806.1300</td>
#     </tr>
#     <tr>
#       <th>3hhcoa_c</th>
#       <td>-816.0020</td>
#     </tr>
#     <tr>
#       <th>3hhdcoa_c</th>
#       <td>-799.5490</td>
#     </tr>
#     <tr>
#       <th>3hocoa_c</th>
#       <td>-812.7110</td>
#     </tr>
#     <tr>
#       <th>3hodcoa_c</th>
#       <td>-796.2580</td>
#     </tr>
#     <tr>
#       <th>3hpppn_c</th>
#       <td>-87.3972</td>
#     </tr>
#     <tr>
#       <th>3htdcoa_c</th>
#       <td>-802.8390</td>
#     </tr>
#     <tr>
#       <th>3ig3p_c</th>
#       <td>-267.2660</td>
#     </tr>
#     <tr>
#       <th>3mob_c</th>
#       <td>-111.0380</td>
#     </tr>
#     <tr>
#       <th>3mop_c</th>
#       <td>-109.3930</td>
#     </tr>
#     <tr>
#       <th>3odcoa_c</th>
#       <td>-801.4280</td>
#     </tr>
#     <tr>
#       <th>3oddcoa_c</th>
#       <td>-798.1370</td>
#     </tr>
#     <tr>
#       <th>3ohcoa_c</th>
#       <td>-808.0090</td>
#     </tr>
#     <tr>
#       <th>3ohdcoa_c</th>
#       <td>-791.5560</td>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-30d16049d151> in <module>()
#      23 display(HTML(mu0.to_frame().to_html()))
#      24
# ---> 25 idx = fullS.index.intersection(mu0.index)
#      26
#      27 deltaG0 = fullS.loc[idx].T.dot(mu0[idx])
#
# NameError: name 'fullS' is not defined

# %% [markdown]
# # Boltzmann

# %%
cat PPP_Gly_TCA_A-COA-Bys1_concs_mod.in
# Out:
# VOLUME 1.0e-15
# CONC_UNITS 1.0e-0
# D-GLUCOPYRANOSE_6-PHOSPHATE     1.00e-03        F
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       1.00e-03        V
# FRUCTOSE_1,6-BISPHOSPHATE       5.399237e-04    V
# ORTHOPHOSPHATE  2.0e-02    F
# 2-PHOSPHO-D-GLYCERATE   2.343639e-03 V
# GLYCERONE_PHOSPHATE     2.877076e-06       V
# 3-PHOSPHO-D-GLYCERATE   4.182558e-05    V
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE 2.536071e-03    V
# D-GLYCERALDEHYDE_3-PHOSPHATE    1.00e-03        F
# PHOSPHOENOLPYRUVATE     1.00e-03        V
# PYRUVATE        1.00e-03        V
# D-XYLULOSE_5-PHOSPHATE  2.320598e-06    F
# AN_ELECTRON-TRANSFER_QUINONE 	1.00e-03	F
# SUCCINATE 	1.00e-05	V
# AN_ELECTRON-TRANSFER_QUINOL 	1.00e-03	F
# FUMARATE 	1.00e-05	V
# SEDOHEPTULOSE_7-PHOSPHATE 	1.00e-05	V
# ALPHA-D-RIBOSE_5-PHOSPHATE 	1.00e-05	V
# D-RIBULOSE_5-PHOSPHATE 	1.00e-05	V
# D-ERYTHROSE_4-PHOSPHATE 	1.00e-05	V
# NADP+ 	2.10e-06	F
# NADPH 	1.20e-04	F
# SUCCINATE 	1.00e-05	V
# CITRATE 	1.00e-05	V
# GLYOXYLATE 	1.00e-05	V
# ACETYL-COA 	1.00e-05	V
# CIS-ACONITATE 	1.00e-05	V
# D-THREO-ISOCITRATE 	1.00e-05	V
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE 	1.00e-05	V
# D-GLUCONATE_6-PHOSPHATE 	1.00e-05	V
# SUCCINATE_SEMIALDEHYDE 	1.00e-05	V
# 2-OXOGLUTARATE 	1.00e-05	V
# COA 	1.40e-03	F
# SUCCINYL-COA 	1.00e-05	V
# CO2 	1.00e-04 F
# OXALOACETATE 	1.00e-05	V
# MALATE 	1.00e-05	V
# FUMARATE 	1.00e-05	V
# H2O 	1.00e-0	 F
# ATP     9.60e-03        F
# ADP     5.60e-04        F
# NAD+    2.60e-03        F
# NADH    8.30e-05        F

# %%
cat PPP_Gly_TCA_A-COA-Bys1_rxns_mod.dat
# Out:
# REACTION        PFKh  :: 6PFRUCTPHOS-RXN
# LEFT    ATP     +       BETA-D-FRUCTOFURANOSE_6-PHOSPHATE
# RIGHT         ADP     +       FRUCTOSE_1,6-BISPHOSPHATE
# DGZERO  -23.300000
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        BFBPh  :: F16BDEPHOS-RXN
# LEFT    FRUCTOSE_1,6-BISPHOSPHATE       +       H2O
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       ORTHOPHOSPHATE
# DGZERO  6.8935547
# ENZYME_LEVEL    0.0
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        FBAF  :: F16ALDOLASE-RXN
# LEFT    FRUCTOSE_1,6-BISPHOSPHATE
# RIGHT   GLYCERONE_PHOSPHATE     +       D-GLYCERALDEHYDE_3-PHOSPHATE
# DGZERO  8.226501
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        TPI  :: TRIOSEPISOMERIZATION-RXN
# LEFT    D-GLYCERALDEHYDE_3-PHOSPHATE
# RIGHT   GLYCERONE_PHOSPHATE
# DGZERO  -1.8299866
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        G6PIh  :: GAPOXNPHOSPHN-RXN
# LEFT    D-GLYCERALDEHYDE_3-PHOSPHATE    +       ORTHOPHOSPHATE  +       NAD+
# RIGHT         3-PHOSPHO-D-GLYCEROYL_PHOSPHATE +       NADH
# DGZERO  -15.19458
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PGKm  :: PHOSGLYPHOS-RXN
# LEFT    3-PHOSPHO-D-GLYCERATE   +       ATP
# RIGHT   3-PHOSPHO-D-GLYCEROYL_PHOSPHATE +       ADP
# DGZERO  -7.51001
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PGM  :: RXN-15513
# LEFT    2-PHOSPHO-D-GLYCERATE
# RIGHT   3-PHOSPHO-D-GLYCERATE
# DGZERO  -1.3200073
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        ENOf  :: 2PGADEHYDRAT-RXN
# LEFT    2-PHOSPHO-D-GLYCERATE
# RIGHT   PHOSPHOENOLPYRUVATE     +       H2O
# DGZERO  -0.18701172
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        PYKf :: PEPDEPHOS-RXN
# LEFT       PHOSPHOENOLPYRUVATE     +       ADP
# RIGHT   PYRUVATE        +       ATP
# DGZERO  -2.234192
# DGZERO_UNITS    KJ/MOL
# PATHWAY PPP
# //
# REACTION    PDHm  :: PYRUVDEH-RXN
# LEFT    COA + NAD+ + PYRUVATE
# RIGHT   ACETYL-COA + CO2 + NADH
# DGZERO  -2.482891e+01
# DGZERO_UNITS    KJ/MOL
# COMMENT COMMENT PYRUVATE DEHYDROGENASE SUMMARY Rxn from neurospora model
# PATHWAY pyruvate dehydrogenase
# //
# REACTION      CS  :: CITSYN-RXN
# LEFT    ACETYL-COA      +       H2O     +       OXALOACETATE
# RIGHT   CITRATE +       COA
# DGZERO  -10.515259
# DGZERO_UNITS    KJ/MOL
# PATHWAY ACETYL-COA to TCA
# //
# REACTION        ACONITATEHYDR__RXN :: ACONITATEHYDR-RXN
# LEFT    CIS-ACONITATE   +       H2O
# RIGHT   D-THREO-ISOCITRATE
# DGZERO  -3.1329956
# DGZERO_UNITS    KJ/MOL
# //
# REACTION	ICDHxm  :: ISOCITRATE-DEHYDROGENASE-NAD+-RXN
# LEFT    D-THREO-ISOCITRATE      +       NAD+
# RIGHT   2-OXOGLUTARATE  +       CO2     +       NADH
# DGZERO  1.6241455
# ENZYME_LEVEL    0.0
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        ISOCIT__CLEAV__RXN :: ISOCIT-CLEAV-RXN
# LEFT    D-THREO-ISOCITRATE
# RIGHT   GLYOXYLATE      +       SUCCINATE
# DGZERO  3.2682343
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        MALSp  :: MALSYN-RXN
# LEFT    ACETYL-COA      +       H2O     +       GLYOXYLATE
# RIGHT   MALATE  +       COA
# DGZERO  -9.251221
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        OXGDC  :: RXN-7774
# LEFT            2-OXOGLUTARATE
# RIGHT   SUCCINATE_SEMIALDEHYDE  +       CO2
# DGZERO  -2.1417694
# DGZERO_UNITS    KJ/MOL
# //
# REACTION       AKGDm  :: 2OXOGLUTARATEDEH-RXN
# LEFT    2-OXOGLUTARATE  +       COA     +       NAD+
# RIGHT   SUCCINYL-COA    +       CO2     +       NADH
# DGZERO  -11.366394
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        SUCOAS  :: SUCCCOASYN-RXN
# LEFT    SUCCINYL-COA    +       ADP     +       ORTHOPHOSPHATE
# RIGHT   SUCCINATE       +       COA     +       ATP
# DGZERO  -1.0540771
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        SUCD1m  :: RXN-14971
# LEFT    AN_ELECTRON-TRANSFER_QUINONE    +       SUCCINATE
# RIGHT   AN_ELECTRON-TRANSFER_QUINOL     +       FUMARATE
# DGZERO  22.757736
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        FUMm  :: FUMHYDR-RXN
# LEFT    FUMARATE        +       H2O
# RIGHT   MALATE
# DGZERO  0.6130066
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        MDHm :: MALATE-DEH-RXN
# LEFT    MALATE  +       NAD+
# RIGHT   OXALOACETATE    +       NADH
# DGZERO  4.461792
# DGZERO_UNITS    KJ/MOL
# //
# REACTION        G6PDH2r  :: GLU6PDEHYDROG-RXN
# LEFT    D-GLUCOPYRANOSE_6-PHOSPHATE     +       NADP+
# RIGHT   6-PHOSPHO_D-GLUCONO-1,5-LACTONE +       NADPH
# DGZERO  -5.9264526
# DGZERO_UNITS    KJ/MOL
# PATHWAY  PPP
# //
# REACTION       PGLh  :: 6PGLUCONOLACT-RXN
# LEFT    6-PHOSPHO_D-GLUCONO-1,5-LACTONE +       H2O
# RIGHT           D-GLUCONATE_6-PHOSPHATE
# DGZERO  -7.355438
# DGZERO_UNITS    KJ/MOL
# PATHWAY PPP
# //
# REACTION        PGDHh  :: RXN-9952
# LEFT    D-GLUCONATE_6-PHOSPHATE +       NADP+
# RIGHT   D-RIBULOSE_5-PHOSPHATE  +       CO2     +       NADPH
# DGZERO  -1.3841553
# DGZERO_UNITS    KJ/MOL
# PATHWAY PPP
# //
# REACTION        RPEh  :: RIBULP3EPIM-RXN
# LEFT    D-RIBULOSE_5-PHOSPHATE
# RIGHT   D-XYLULOSE_5-PHOSPHATE
# DGZERO  -00.00000
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY PPP
# //
# REACTION        RPI :: RIB5PISOM-RXN
# RIGHT   D-RIBULOSE_5-PHOSPHATE
# LEFT    ALPHA-D-RIBOSE_5-PHOSPHATE
# DGZERO  0.46000
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# //
# REACTION        TKT1 :: 1TRANSKETO-RXN
# LEFT    SEDOHEPTULOSE_7-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# RIGHT   ALPHA-D-RIBOSE_5-PHOSPHATE      +       D-XYLULOSE_5-PHOSPHATE
# DGZERO  -0.1821793
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# //
# REACTION        TALA  :: TRANSALDOL-RXN
# LEFT    SEDOHEPTULOSE_7-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       D-ERYTHROSE_4-PHOSPHATE
# DGZERO  -8.640509
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY RUBISCO SHUNT, PENTOSE PHOSPHATE PATHWAY
# COMMENT From Equilibrator pH 7.5 IS 0.15
# //
# REACTION        TKT2 :: 2TRANSKETO-RXN
# LEFT    D-ERYTHROSE_4-PHOSPHATE +       D-XYLULOSE_5-PHOSPHATE
# RIGHT   BETA-D-FRUCTOFURANOSE_6-PHOSPHATE       +       D-GLYCERALDEHYDE_3-PHOSPHATE
# DGZERO  4.697130
# DGZERO_UNITS    KJ/MOL
# ENZYME_LEVEL    0.0
# PATHWAY CALVIN CYCLE, PENTOSE PHOSPHATE PATHWAY, RUBISCO SHUNT
# COMMENT From Equilibrator pH 7.5, IS 0.15
# //

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import subprocess
import re
import os
from IPython.core.display import display
pd.set_option('display.max_columns', None,'display.max_rows', None)

#args = ("/Users/kuma889/Projects/Boltzmann/Boltz/05_boltz_bug_fix_4432/boltzmann", "central_metabolism_dg0.in")

popen = subprocess.Popen(args, stdout=subprocess.PIPE)
popen.wait()
output = popen.stdout.read()
print(output)
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-36-26314c68f544> in <module>()
#      11 #args = ("/Users/kuma889/Projects/Boltzmann/Boltz/05_boltz_bug_fix_4432/boltzmann", "central_metabolism_dg0.in")
#      12
# ---> 13 popen = subprocess.Popen(args, stdout=subprocess.PIPE)
#      14 popen.wait()
#      15 output = popen.stdout.read()
#
# NameError: name 'args' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import subprocess
import re
import os
from IPython.core.display import display
#from ipynb_latex_setup import *
# %matplotlib inline
N_avogadro = 6.022140857e+23
VolCell = 1.0e-15
Concentration2Count = N_avogadro * VolCell
concentration_increment = 1/(N_avogadro*VolCell)
RT = 8.3144598e-03 * 298.15

# %% [markdown]
# ## Analyze Simulation Results for centeral Metabolism

# %% [markdown]
#  ### Derivatives from ODE thermodynamic optimization simulation

# %%
# Read boltzmann stochastic reaction likelihoods
ode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_dconcs',header=0,index_col=0)
#ode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.rstrt',header=None,index_col=0,skiprows=2)
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#ode_metabolites.columns = column_namesode_derivatives = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_dconcs',header=0,index_col=0)
# Get the absolute value of the derivatives:
abs_derivatives = np.abs(ode_derivatives.iloc[-1,:])
display(abs_derivatives.sort_values())
#plt.figure();ode_derivatives.iloc[-5000:-1500,:].plot(legend=False,logx=True,logy=False,figsize=(10, 10))
plt.figure();ode_derivatives.plot(legend=False,logx=False,logy=False,figsize=(10, 10))
plt.yscale('symlog')
#plt.legend(bbox_to_anchor=(1.35, 1.05),bbox_transform=plt.gcf().transFigure)
# Out:
# 2-OXOGLUTARATE:                       0.000000e+00
# SUCCINATE:                            0.000000e+00
# SEDOHEPTULOSE_7-PHOSPHATE:            0.000000e+00
# ORTHOPHOSPHATE:                       0.000000e+00
# NADPH:                                0.000000e+00
# NADP+:                                0.000000e+00
# NADH:                                 0.000000e+00
# NAD+:                                 0.000000e+00
# MALATE:                               0.000000e+00
# GLYOXYLATE:                           0.000000e+00
# FUMARATE:                             0.000000e+00
# D-XYLULOSE_5-PHOSPHATE:               0.000000e+00
# D-THREO-ISOCITRATE:                   0.000000e+00
# SUCCINATE_SEMIALDEHYDE:               0.000000e+00
# D-GLUCOPYRANOSE_6-PHOSPHATE:          0.000000e+00
# D-ERYTHROSE_4-PHOSPHATE:              0.000000e+00
# D-GLYCERALDEHYDE_3-PHOSPHATE:         0.000000e+00
# ALPHA-D-RIBOSE_5-PHOSPHATE:           0.000000e+00
# ADP:                                  0.000000e+00
# COA:                                  0.000000e+00
# AN_ELECTRON-TRANSFER_QUINOL:          0.000000e+00
# AN_ELECTRON-TRANSFER_QUINONE:         0.000000e+00
# ATP:                                  0.000000e+00
# SUCCINYL-COA:                         0.000000e+00
# CIS-ACONITATE:                        0.000000e+00
# CO2:                                  0.000000e+00
# D-RIBULOSE_5-PHOSPHATE:               1.110223e-16
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE:      3.330669e-16
# D-GLUCONATE_6-PHOSPHATE:              3.330669e-16
# CITRATE:                              5.637829e-11
# OXALOACETATE:                         5.637829e-11
# GLYCERONE_PHOSPHATE:                  5.611745e-08
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE:    3.915952e-06
# PHOSPHOENOLPYRUVATE:                  2.030561e-05
# 2-PHOSPHO-D-GLYCERATE:                5.289943e-04
# PYRUVATE:                             1.393995e-03
# 3-PHOSPHO-D-GLYCERATE:                5.567154e-01
# FRUCTOSE_1,6-BISPHOSPHATE:            8.111934e-01
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE:      3.178567e+01
# ACETYL-COA:                           1.257616e+02
# Name: 9999.802, dtype: float64

# %%
#display(ode_derivatives.loc[0.0].sort_values())

# %% [markdown]
# ### Likelihoods from Deterministic Simulation

# %%
# Read boltzmann ODE reaction likelihoods
columns = np.arange(1,52,1)
fwd_column_idx = [x for x in np.arange(0,52,2)]
rev_column_idx = [x for x in np.arange(1,52,2)]
#rev_columns = np.arange(0,55,2)
ode_likelihoods_timeseries = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd',header=1, index_col = 0, quoting=2)
ode_fwd_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,fwd_column_idx]
ode_rev_likelihoods_timeseries = ode_likelihoods_timeseries.iloc[:,rev_column_idx]

ode_fwd_likelihoods_timeseries.columns = [x.split("f_")[-1] for x in ode_fwd_likelihoods_timeseries.columns]
ode_rev_likelihoods_timeseries.columns = [x.split("r_")[-1] for x in ode_rev_likelihoods_timeseries.columns]
fwd_column = ode_likelihoods_timeseries.iloc[:,fwd_column_idx].columns
rev_column = ode_likelihoods_timeseries.iloc[:,rev_column_idx].columns
#column_names = [x.split("f_")[-1] for x in ode_likelihoods.columns]
#ode_likelihoods.columns = column_names

#plt.figure()
#ode_likelihoods.iloc[:,rev_column_idx].plot(legend=True,logx=True,figsize=(12, 12))
ode_fwd_likelihoods_timeseries.plot(legend=True,logx=False,figsize=(9, 9))
plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.25, 0.75),bbox_transform=plt.gcf().transFigure)
np.log10(ode_fwd_likelihoods_timeseries.iloc[-100:]).mean()
# Out:
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/ipykernel/__main__.py:22: RuntimeWarning: divide by zero encountered in log10
# PFKh                  -0.000002
# BFBPh                      -inf
# FBAF                  -0.172201
# TPI                    0.172200
# G6PIh                  2.199592
# PGKm                  -2.101766
# PGM                   -2.099840
# ENOf                   2.099839
# PYKf                   2.099838
# PDHm                   2.099834
# CS                    -8.089614
# ACONITATEHYDR__RXN   -39.878175
# ICDHxm                     -inf
# ISOCIT__CLEAV__RXN   -39.901870
# MALSp                -23.398373
# OXGDC                -19.049059
# AKGDm                 -7.326127
# SUCOAS                -7.745571
# SUCD1m               -12.161346
# FUMm                 -16.321202
# MDHm                 -18.447997
# G6PDH2r               -0.000177
# PGLh                  -0.000002
# PGDHh                 -0.185417
# RPEh                       -inf
# RPI                        -inf
# dtype: float64

# %% [markdown]
# ode_likelihoods_steadystate = pd.DataFrame(data = ode_fwd_likelihoods_timeseries.iloc[-20:].mean(),
#                                            index = ode_fwd_likelihoods_timeseries.columns,
#                                           columns =['Forward'])
# ode_likelihoods_steadystate['Reverse'] = ode_rev_likelihoods_timeseries.iloc[-20:].mean()
# ode_likelihoods_steadystate['For-Rev'] = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
# ode_likelihoods_steadystate['Rxn Probabilities'] = ode_likelihoods_steadystate['For-Rev']/np.sum(abs(ode_likelihoods_steadystate['For-Rev']))
# ode_likelihoods_steadystate

# %%
ode_likelihoods_steadystate = pd.DataFrame(data = ode_fwd_likelihoods_timeseries.iloc[-100:].mean(), 
                                           index = ode_fwd_likelihoods_timeseries.columns,
                                          columns =['Forward'])

ode_likelihoods_steadystate['Reverse'] = ode_rev_likelihoods_timeseries.iloc[-100:].mean()
ode_likelihoods_steadystate['For-Rev'] = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
ode_likelihoods_steadystate['Rxn Probabilities'] = ode_likelihoods_steadystate['For-Rev']/np.sum(abs(ode_likelihoods_steadystate['For-Rev']))
ode_likelihoods_steadystate
# Out:
#                          Forward       Reverse       For-Rev  \
# PFKh                9.999965e-01  1.000000e+00 -3.510000e-06
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                6.726657e-01  1.486619e+00 -8.139533e-01
# TPI                 1.486619e+00  6.726657e-01  8.139534e-01
# G6PIh               1.583404e+02  6.315372e-03  1.583341e+02
# PGKm                7.911056e-03  1.264050e+02 -1.263971e+02
# PGM                 7.946203e-03  1.258463e+02 -1.258383e+02
# ENOf                1.258458e+02  7.946237e-03  1.258378e+02
# PYKf                1.258457e+02  7.946213e-03  1.258378e+02
# PDHm                1.258443e+02  7.946021e-03  1.258364e+02
# CS                  8.135526e-09  5.662864e-11  8.078897e-09
# ACONITATEHYDR__RXN  1.323811e-40  1.323811e-40  0.000000e+00
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  1.253522e-40  3.328243e-48  1.253522e-40
# MALSp               3.996015e-24  8.026086e-33  3.996015e-24
# OXGDC               8.931871e-20  8.931872e-20 -1.800000e-27
# AKGDm               4.719265e-08  3.129758e-16  4.719265e-08
# SUCOAS              1.796512e-08  1.797694e-08 -1.182120e-11
# SUCD1m              6.896921e-13  6.900067e-13 -3.146390e-16
# FUMm                4.773090e-17  3.591116e-16 -3.113807e-16
# MDHm                3.564549e-19  3.117371e-16 -3.113807e-16
# G6PDH2r             9.995928e-01  9.995928e-01  0.000000e+00
# PGLh                9.999954e-01  9.999954e-01  0.000000e+00
# PGDHh               6.525036e-01  6.525036e-01  0.000000e+00
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00
#
#                     Rxn Probabilities
# PFKh                    -4.444673e-09
# BFBPh                    0.000000e+00
# FBAF                    -1.030700e-03
# TPI                      1.030700e-03
# G6PIh                    2.004966e-01
# PGKm                    -1.600552e-01
# PGM                     -1.593477e-01
# ENOf                     1.593470e-01
# PYKf                     1.593470e-01
# PDHm                     1.593452e-01
# CS                       1.023022e-11
# ACONITATEHYDR__RXN       0.000000e+00
# ICDHxm                   0.000000e+00
# ISOCIT__CLEAV__RXN       1.587320e-43
# MALSp                    5.060108e-27
# OXGDC                   -2.279320e-30
# AKGDm                    5.975951e-11
# SUCOAS                  -1.496905e-14
# SUCD1m                  -3.984238e-19
# FUMm                    -3.942978e-19
# MDHm                    -3.942978e-19
# G6PDH2r                  0.000000e+00
# PGLh                     0.000000e+00
# PGDHh                    0.000000e+00
# RPEh                     0.000000e+00
# RPI                      0.000000e+00

# %%
concs = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_concs',index_col=0)#.apply(np.log)
log_concs = concs.apply(np.log).T
log_concs.index
mets = {'2-PHOSPHO-D-GLYCERATE':'2-PG', 
        '3-PHOSPHO-D-GLYCERATE':'G3P',
        '3-PHOSPHO-D-GLYCEROYL_PHOSPHATE':'DPG', 
        'ADP':'ADP', 
        'AMP':'AMP', 
        'ATP':'ATP',
       'BETA-D-FRUCTOFURANOSE_6-PHOSPHATE':'FRUCTOSE-6P', 
        'D-GLUCOPYRANOSE_6-PHOSPHATE':'D-glucopyranose-6-phosphate',
       'D-GLYCERALDEHYDE_3-PHOSPHATE':'GAP', 
        'FRUCTOSE_1,6-BISPHOSPHATE':'FRUCTOSE-16-DIPHOSPHATE',
       'GLYCERONE_PHOSPHATE':'DIHYDROXY-ACETONE-PHOSPHATE', 
        'H+':'PROTON', 
        'NAD+':'NAD', 
        'NADH':'NADH', 
        'ORTHOPHOSPHATE':'Pi',
       'PHOSPHOENOLPYRUVATE':'PHOSPHO-ENOL-PYRUVATE', 
        'PYRUVATE':'PYRUVATE'}

log_concs.index = [mets[m] for m in log_concs.index]
log_concs.index.name='$Metabolite'

log_concs.to_csv('central_metabolism_dg0_rxns_GLy.log_concs.tab',sep='\t')
#og_concs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-eaff86b9b991> in <module>()
#      20         'PYRUVATE':'PYRUVATE'}
#      21
# ---> 22 log_concs.index = [mets[m] for m in log_concs.index]
#      23 log_concs.index.name='$Metabolite'
#      24
#
# KeyError: '2-OXOGLUTARATE'

# %%
import pandas as pd
import numpy as np
import re, os
def to_chr(  matchobj ):
        return chr(int(matchobj.group(1)))
def to_ord( matchobj ):
        return '__{}__'.format(ord(matchobj.group(0)))    
def munge( sbmlid ):
    alphaRE = re.compile(r'[^A-Za-z_]')
    m = alphaRE.match(sbmlid[0])
    if m:
        sbmlid = '_{}'.format(sbmlid)
    alphanumRE = re.compile(r'[^A-Za-z0-9_]')
    sbmlid = alphanumRE.sub(to_ord, sbmlid)
    return sbmlid
def unmunge( sbmlid ):
    ordRE = re.compile('__([0-9]+)__')
    if '_' == sbmlid[0] and '_' != sbmlid[1]:
        sbmlid = sbmlid[1:]
    return ordRE.sub( to_chr, sbmlid)    
def unmunge_model( model ):     
    for met in model.metabolites:
        met.id = unmunge(met.id)
    for rxn in model.reactions:
        rxn.id = unmunge(rxn.id)
    return model

# %%
likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd',skiprows=1).T
likelihoods.iloc[3:]
forward_likelihoods = likelihoods.iloc[3::2]
idx = [unmunge(rxn[2:]) for rxn in forward_likelihoods.index]
forward_likelihoods.index = idx
display(forward_likelihoods)

backward_likelihoods = likelihoods.iloc[4::2]
backward_likelihoods.index = idx
display(backward_likelihoods)

net_likelihoods = ode_likelihoods_steadystate['Forward'] - ode_likelihoods_steadystate['Reverse']
net_likelihoods.index.name = '$FrameId'
display(net_likelihoods)

net_likelihoods.columns = [str(c) for c in net_likelihoods.columns]
net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_net_likelihood.tab', sep='\t')

ode_likelihoods_steadystate.columns = [str(c) for c in ode_likelihoods_steadystate['For-Rev'].columns]
ode_likelihoods_steadystate['For-Rev'].to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_likelihood.tab', sep='\t')
# Out:
#                            0             1             2             3      \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                1.127516e-05  1.127727e-05  1.127990e-05  1.128329e-05
# TPI                 7.268828e+02  7.270146e+02  7.271799e+02  7.273920e+02
# G6PIh               6.243989e+10  5.547096e+10  4.932640e+10  4.379733e+10
# PGKm                9.686568e-03  8.605449e-03  7.652218e-03  6.794470e-03
# PGM                 6.049886e+02  6.049886e+02  6.049885e+02  6.049884e+02
# ENOf                9.285248e+00  9.285249e+00  9.285249e+00  9.285250e+00
# PYKf                7.281170e+03  7.309592e+03  7.338128e+03  7.368441e+03
# PDHm                7.473040e+08  5.745937e+08  4.664457e+08  3.887895e+08
# CS                  4.980516e+05  6.448140e+05  7.903952e+05  9.428128e+05
# ACONITATEHYDR__RXN  3.538604e+00  3.538556e+00  3.538497e+00  3.538421e+00
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  4.441675e-05  4.442681e-05  4.444213e-05  4.446535e-05
# MALSp               2.801278e+05  3.627775e+05  4.448836e+05  5.310471e+05
# OXGDC               2.759673e-04  2.538070e-04  2.301030e-04  2.046330e-04
# AKGDm               1.384013e+08  1.187236e+08  1.004092e+08  8.328655e+07
# SUCOAS              3.923967e-01  4.207084e-01  4.509936e-01  4.835373e-01
# SUCD1m              1.029727e-04  1.029725e-04  1.029722e-04  1.029719e-04
# FUMm                6.714857e-01  6.713526e-01  6.711451e-01  6.708254e-01
# MDHm                1.477962e-03  1.478753e-03  1.479993e-03  1.481916e-03
# G6PDH2r             1.911117e+01  1.911117e+01  1.911117e+01  1.911117e+01
# PGLh                1.942242e+01  1.939986e+01  1.937170e+01  1.933582e+01
# PGDHh               5.085458e-07  5.097313e-07  5.112183e-07  5.131257e-07
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            4             5             6             7      \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                1.128765e-05  1.129325e-05  1.130049e-05  1.131016e-05
# TPI                 7.276656e+02  7.280162e+02  7.284700e+02  7.290759e+02
# G6PIh               3.880858e+10  3.437433e+10  3.039691e+10  2.675205e+10
# PGKm                6.020544e-03  5.332642e-03  4.715610e-03  4.150167e-03
# PGM                 6.049883e+02  6.049881e+02  6.049878e+02  6.049875e+02
# ENOf                9.285251e+00  9.285252e+00  9.285253e+00  9.285255e+00
# PYKf                7.401633e+03  7.438130e+03  7.479141e+03  7.526947e+03
# PDHm                3.289046e+08  2.813342e+08  2.420722e+08  2.082785e+08
# CS                  1.106689e+06  1.282631e+06  1.474172e+06  1.687875e+06
# ACONITATEHYDR__RXN  3.538323e+00  3.538198e+00  3.538036e+00  3.537821e+00
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  4.450020e-05  4.455175e-05  4.462824e-05  4.474509e-05
# MALSp               6.240217e+05  7.243924e+05  8.345705e+05  9.590654e+05
# OXGDC               1.775809e-04  1.499174e-04  1.220512e-04  9.423082e-05
# AKGDm               6.745513e+07  5.331029e+07  4.077749e+07  2.969022e+07
# SUCOAS              5.181055e-01  5.534595e-01  5.890797e-01  6.246525e-01
# SUCD1m              1.029716e-04  1.029711e-04  1.029704e-04  1.029696e-04
# FUMm                6.703405e-01  6.696182e-01  6.685428e-01  6.669014e-01
# MDHm                1.484849e-03  1.489248e-03  1.495848e-03  1.506033e-03
# G6PDH2r             1.911117e+01  1.911117e+01  1.911117e+01  1.911117e+01
# PGLh                1.928992e+01  1.923180e+01  1.915762e+01  1.906041e+01
# PGDHh               5.155862e-07  5.187366e-07  5.228131e-07  5.282535e-07
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            8             9          ...              13701  \
# BFBPh               0.000000e+00  0.000000e+00      ...       0.000000e+00
# FBAF                1.132364e-05  1.134453e-05      ...       6.733690e-01
# TPI                 7.299207e+02  7.312296e+02      ...       1.485066e+00
# G6PIh               2.333517e+10  1.993756e+10      ...       1.581535e+02
# PGKm                3.620095e-03  3.093011e-03      ...       7.914994e-03
# PGM                 6.049870e+02  6.049862e+02      ...       7.950071e-03
# ENOf                9.285257e+00  9.285261e+00      ...       1.257845e+02
# PYKf                7.585231e+03  7.663148e+03      ...       1.257845e+02
# PDHm                1.780753e+08  1.492805e+08      ...       1.257831e+02
# CS                  1.932244e+06  2.226411e+06      ...       8.135524e-09
# ACONITATEHYDR__RXN  3.537522e+00  3.537062e+00      ...       1.319016e-40
# ICDHxm              0.000000e+00  0.000000e+00      ...       0.000000e+00
# ISOCIT__CLEAV__RXN  4.493203e-05  4.526844e-05      ...       1.248982e-40
# MALSp               1.104335e+06  1.285600e+06      ...       3.994005e-24
# OXGDC               6.695995e-05  4.052598e-05      ...       8.899523e-20
# AKGDm               1.998172e+07  1.150239e+07      ...       4.702173e-08
# SUCOAS              6.595431e-01  6.934104e-01      ...       1.790006e-08
# SUCD1m              1.029685e-04  1.029668e-04      ...       6.871942e-13
# FUMm                6.642917e-01  6.596702e-01      ...       4.755803e-17
# MDHm                1.522488e-03  1.552408e-03      ...       3.551639e-19
# G6PDH2r             1.911117e+01  1.911117e+01      ...       9.995928e-01
# PGLh                1.892827e+01  1.873094e+01      ...       9.999954e-01
# PGDHh               5.358331e-07  5.475662e-07      ...       6.525036e-01
# RPEh                0.000000e+00  0.000000e+00      ...       0.000000e+00
# RPI                 0.000000e+00  0.000000e+00      ...       0.000000e+00
# TKT1                0.000000e+00  0.000000e+00      ...       0.000000e+00
# TALA                0.000000e+00  0.000000e+00      ...       0.000000e+00
# TKT2                0.000000e+00  0.000000e+00      ...       0.000000e+00
#
#                            13702         13703         13704         13705  \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                6.733863e-01  6.734037e-01  6.734210e-01  6.734383e-01
# TPI                 1.485027e+00  1.484989e+00  1.484951e+00  1.484913e+00
# G6PIh               1.581489e+02  1.581444e+02  1.581398e+02  1.581352e+02
# PGKm                7.915091e-03  7.915188e-03  7.915285e-03  7.915382e-03
# PGM                 7.950166e-03  7.950261e-03  7.950357e-03  7.950452e-03
# ENOf                1.257830e+02  1.257815e+02  1.257800e+02  1.257785e+02
# PYKf                1.257830e+02  1.257815e+02  1.257800e+02  1.257785e+02
# PDHm                1.257816e+02  1.257801e+02  1.257786e+02  1.257771e+02
# CS                  8.135524e-09  8.135524e-09  8.135524e-09  8.135524e-09
# ACONITATEHYDR__RXN  1.318899e-40  1.318781e-40  1.318663e-40  1.318546e-40
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  1.248870e-40  1.248759e-40  1.248648e-40  1.248536e-40
# MALSp               3.993955e-24  3.993906e-24  3.993856e-24  3.993807e-24
# OXGDC               8.898729e-20  8.897935e-20  8.897141e-20  8.896348e-20
# AKGDm               4.701753e-08  4.701334e-08  4.700915e-08  4.700495e-08
# SUCOAS              1.789846e-08  1.789686e-08  1.789527e-08  1.789367e-08
# SUCD1m              6.871329e-13  6.870716e-13  6.870104e-13  6.869491e-13
# FUMm                4.755379e-17  4.754955e-17  4.754530e-17  4.754106e-17
# MDHm                3.551322e-19  3.551005e-19  3.550689e-19  3.550372e-19
# G6PDH2r             9.995928e-01  9.995928e-01  9.995928e-01  9.995928e-01
# PGLh                9.999954e-01  9.999954e-01  9.999954e-01  9.999954e-01
# PGDHh               6.525036e-01  6.525036e-01  6.525036e-01  6.525036e-01
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            13706         13707         13708         13709  \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                6.734556e-01  6.734729e-01  6.734902e-01  6.735075e-01
# TPI                 1.484875e+00  1.484837e+00  1.484798e+00  1.484760e+00
# G6PIh               1.581306e+02  1.581260e+02  1.581214e+02  1.581168e+02
# PGKm                7.915479e-03  7.915576e-03  7.915672e-03  7.915769e-03
# PGM                 7.950547e-03  7.950642e-03  7.950738e-03  7.950833e-03
# ENOf                1.257770e+02  1.257755e+02  1.257740e+02  1.257725e+02
# PYKf                1.257770e+02  1.257755e+02  1.257739e+02  1.257724e+02
# PDHm                1.257756e+02  1.257741e+02  1.257726e+02  1.257710e+02
# CS                  8.135524e-09  8.135524e-09  8.135524e-09  8.135523e-09
# ACONITATEHYDR__RXN  1.318428e-40  1.318311e-40  1.318193e-40  1.318076e-40
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  1.248425e-40  1.248313e-40  1.248202e-40  1.248091e-40
# MALSp               3.993757e-24  3.993708e-24  3.993658e-24  3.993609e-24
# OXGDC               8.895554e-20  8.894761e-20  8.893968e-20  8.893175e-20
# AKGDm               4.700076e-08  4.699657e-08  4.699238e-08  4.698819e-08
# SUCOAS              1.789207e-08  1.789048e-08  1.788888e-08  1.788729e-08
# SUCD1m              6.868878e-13  6.868266e-13  6.867653e-13  6.867041e-13
# FUMm                4.753682e-17  4.753258e-17  4.752835e-17  4.752411e-17
# MDHm                3.550055e-19  3.549739e-19  3.549422e-19  3.549106e-19
# G6PDH2r             9.995928e-01  9.995928e-01  9.995928e-01  9.995928e-01
# PGLh                9.999954e-01  9.999954e-01  9.999954e-01  9.999954e-01
# PGDHh               6.525036e-01  6.525036e-01  6.525036e-01  6.525036e-01
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            13710
# BFBPh               0.000000e+00
# FBAF                6.735248e-01
# TPI                 1.484722e+00
# G6PIh               1.581122e+02
# PGKm                7.915866e-03
# PGM                 7.950928e-03
# ENOf                1.257710e+02
# PYKf                1.257709e+02
# PDHm                1.257695e+02
# CS                  8.135523e-09
# ACONITATEHYDR__RXN  1.317958e-40
# ICDHxm              0.000000e+00
# ISOCIT__CLEAV__RXN  1.247980e-40
# MALSp               3.993560e-24
# OXGDC               8.892382e-20
# AKGDm               4.698400e-08
# SUCOAS              1.788569e-08
# SUCD1m              6.866429e-13
# FUMm                4.751987e-17
# MDHm                3.548789e-19
# G6PDH2r             9.995928e-01
# PGLh                9.999954e-01
# PGDHh               6.525036e-01
# RPEh                0.000000e+00
# RPI                 0.000000e+00
# TKT1                0.000000e+00
# TALA                0.000000e+00
# TKT2                0.000000e+00
#
# [28 rows x 13711 columns]
#                            0             1             2             3      \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                8.863893e+04  8.862240e+04  8.860166e+04  8.857507e+04
# TPI                 1.374942e-03  1.374692e-03  1.374380e-03  1.373979e-03
# G6PIh               1.601503e-11  1.802704e-11  2.027265e-11  2.283192e-11
# PGKm                1.032313e+02  1.162004e+02  1.306754e+02  1.471721e+02
# PGM                 1.652857e-03  1.652857e-03  1.652857e-03  1.652857e-03
# ENOf                1.076975e-01  1.076975e-01  1.076974e-01  1.076974e-01
# PYKf                1.373397e-04  1.368057e-04  1.362737e-04  1.357130e-04
# PDHm                1.337920e-09  1.740120e-09  2.143615e-09  2.571811e-09
# CS                  2.006901e-06  1.550166e-06  1.264667e-06  1.060232e-06
# ACONITATEHYDR__RXN  2.825035e-01  2.825073e-01  2.825120e-01  2.825181e-01
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  2.250282e+04  2.249772e+04  2.248997e+04  2.247822e+04
# MALSp               3.568157e-06  2.755322e-06  2.246851e-06  1.882319e-06
# OXGDC               3.622321e+03  3.938531e+03  4.344173e+03  4.884750e+03
# AKGDm               7.222684e-09  8.419755e-09  9.955400e-09  1.200190e-08
# SUCOAS              2.547605e+00  2.376189e+00  2.216644e+00  2.067476e+00
# SUCD1m              9.708058e+03  9.708076e+03  9.708098e+03  9.708126e+03
# FUMm                1.488741e+00  1.489036e+00  1.489496e+00  1.490206e+00
# MDHm                6.763686e+02  6.760071e+02  6.754404e+02  6.745639e+02
# G6PDH2r             5.227459e-02  5.227459e-02  5.227459e-02  5.227459e-02
# PGLh                5.146979e-02  5.152968e-02  5.160459e-02  5.170037e-02
# PGDHh               1.964125e+06  1.959557e+06  1.953858e+06  1.946595e+06
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            4             5             6             7      \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                8.854079e+04  8.849691e+04  8.844017e+04  8.836452e+04
# TPI                 1.373462e-03  1.372800e-03  1.371944e-03  1.370803e-03
# G6PIh               2.576691e-11  2.909081e-11  3.289733e-11  3.737947e-11
# PGKm                1.660908e+02  1.875162e+02  2.120525e+02  2.409438e+02
# PGM                 1.652858e-03  1.652858e-03  1.652859e-03  1.652860e-03
# ENOf                1.076974e-01  1.076974e-01  1.076974e-01  1.076974e-01
# PYKf                1.351044e-04  1.344415e-04  1.337043e-04  1.328551e-04
# PDHm                3.040101e-09  3.554176e-09  4.130660e-09  4.800896e-09
# CS                  9.032436e-07  7.793498e-07  6.780921e-07  5.922420e-07
# ACONITATEHYDR__RXN  2.825259e-01  2.825359e-01  2.825488e-01  2.825660e-01
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  2.246061e+04  2.243462e+04  2.239616e+04  2.233767e+04
# MALSp               1.601883e-06  1.379940e-06  1.197771e-06  1.042296e-06
# OXGDC               5.628673e+03  6.666967e+03  8.188536e+03  1.060485e+04
# AKGDm               1.481829e-08  1.874923e-08  2.451009e-08  3.365920e-08
# SUCOAS              1.929550e+00  1.806307e+00  1.697096e+00  1.600459e+00
# SUCD1m              9.708163e+03  9.708209e+03  9.708269e+03  9.708347e+03
# FUMm                1.491284e+00  1.492893e+00  1.495295e+00  1.498976e+00
# MDHm                6.732313e+02  6.712430e+02  6.682810e+02  6.637612e+02
# G6PDH2r             5.227459e-02  5.227459e-02  5.227459e-02  5.227459e-02
# PGLh                5.182339e-02  5.198005e-02  5.218134e-02  5.244751e-02
# PGDHh               1.937305e+06  1.925539e+06  1.910525e+06  1.890849e+06
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            8             9          ...              13701  \
# BFBPh               0.000000e+00  0.000000e+00      ...       0.000000e+00
# FBAF                8.825926e+04  8.809667e+04      ...       1.485066e+00
# TPI                 1.369216e-03  1.366764e-03      ...       6.733690e-01
# G6PIh               4.285279e-11  5.015546e-11      ...       6.322828e-03
# PGKm                2.762240e+02  3.232957e+02      ...       1.263421e+02
# PGM                 1.652861e-03  1.652863e-03      ...       1.257850e+02
# ENOf                1.076974e-01  1.076973e-01      ...       7.950104e-03
# PYKf                1.318343e-04  1.304938e-04      ...       7.950081e-03
# PDHm                5.615200e-09  6.698350e-09      ...       7.949888e-03
# CS                  5.173441e-07  4.489915e-07      ...       5.642356e-11
# ACONITATEHYDR__RXN  2.825899e-01  2.826267e-01      ...       1.319016e-40
# ICDHxm              0.000000e+00  0.000000e+00      ...       0.000000e+00
# ISOCIT__CLEAV__RXN  2.224471e+04  2.207938e+04      ...       3.302489e-48
# MALSp               9.051924e-07  7.775671e-07      ...       7.968005e-33
# OXGDC               1.492078e+04  2.464158e+04      ...       8.899523e-20
# AKGDm               5.000296e-08  8.682362e-08      ...       3.118423e-16
# SUCOAS              1.515801e+00  1.441773e+00      ...       1.791184e-08
# SUCD1m              9.708453e+03  9.708609e+03      ...       6.875077e-13
# FUMm                1.504866e+00  1.515410e+00      ...       3.578110e-16
# MDHm                6.565870e+02  6.439320e+02      ...       3.106081e-16
# G6PDH2r             5.227459e-02  5.227459e-02      ...       9.995928e-01
# PGLh                5.281371e-02  5.337021e-02      ...       9.999954e-01
# PGDHh               1.864102e+06  1.824158e+06      ...       6.525036e-01
# RPEh                0.000000e+00  0.000000e+00      ...       0.000000e+00
# RPI                 0.000000e+00  0.000000e+00      ...       0.000000e+00
# TKT1                0.000000e+00  0.000000e+00      ...       0.000000e+00
# TALA                0.000000e+00  0.000000e+00      ...       0.000000e+00
# TKT2                0.000000e+00  0.000000e+00      ...       0.000000e+00
#
#                            13702         13703         13704         13705  \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                1.485027e+00  1.484989e+00  1.484951e+00  1.484913e+00
# TPI                 6.733863e-01  6.734036e-01  6.734209e-01  6.734383e-01
# G6PIh               6.323012e-03  6.323195e-03  6.323379e-03  6.323562e-03
# PGKm                1.263405e+02  1.263390e+02  1.263374e+02  1.263359e+02
# PGM                 1.257835e+02  1.257820e+02  1.257805e+02  1.257790e+02
# ENOf                7.950199e-03  7.950295e-03  7.950390e-03  7.950485e-03
# PYKf                7.950176e-03  7.950271e-03  7.950366e-03  7.950462e-03
# PDHm                7.949983e-03  7.950079e-03  7.950174e-03  7.950269e-03
# CS                  5.641853e-11  5.641349e-11  5.640846e-11  5.640343e-11
# ACONITATEHYDR__RXN  1.318899e-40  1.318781e-40  1.318663e-40  1.318546e-40
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  3.301859e-48  3.301229e-48  3.300600e-48  3.299970e-48
# MALSp               7.966583e-33  7.965162e-33  7.963741e-33  7.962320e-33
# OXGDC               8.898729e-20  8.897935e-20  8.897142e-20  8.896348e-20
# AKGDm               3.118144e-16  3.117866e-16  3.117588e-16  3.117310e-16
# SUCOAS              1.791024e-08  1.790864e-08  1.790704e-08  1.790544e-08
# SUCD1m              6.874464e-13  6.873851e-13  6.873238e-13  6.872625e-13
# FUMm                3.577791e-16  3.577471e-16  3.577152e-16  3.576833e-16
# MDHm                3.105804e-16  3.105527e-16  3.105250e-16  3.104973e-16
# G6PDH2r             9.995928e-01  9.995928e-01  9.995928e-01  9.995928e-01
# PGLh                9.999954e-01  9.999954e-01  9.999954e-01  9.999954e-01
# PGDHh               6.525036e-01  6.525036e-01  6.525036e-01  6.525036e-01
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            13706         13707         13708         13709  \
# BFBPh               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# FBAF                1.484875e+00  1.484837e+00  1.484798e+00  1.484760e+00
# TPI                 6.734556e-01  6.734729e-01  6.734902e-01  6.735075e-01
# G6PIh               6.323746e-03  6.323929e-03  6.324113e-03  6.324296e-03
# PGKm                1.263344e+02  1.263328e+02  1.263313e+02  1.263297e+02
# PGM                 1.257775e+02  1.257760e+02  1.257745e+02  1.257730e+02
# ENOf                7.950580e-03  7.950676e-03  7.950771e-03  7.950866e-03
# PYKf                7.950557e-03  7.950652e-03  7.950747e-03  7.950842e-03
# PDHm                7.950364e-03  7.950460e-03  7.950555e-03  7.950650e-03
# CS                  5.639840e-11  5.639337e-11  5.638834e-11  5.638332e-11
# ACONITATEHYDR__RXN  1.318428e-40  1.318311e-40  1.318193e-40  1.318076e-40
# ICDHxm              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ISOCIT__CLEAV__RXN  3.299341e-48  3.298711e-48  3.298082e-48  3.297453e-48
# MALSp               7.960900e-33  7.959480e-33  7.958061e-33  7.956642e-33
# OXGDC               8.895555e-20  8.894761e-20  8.893968e-20  8.893175e-20
# AKGDm               3.117032e-16  3.116754e-16  3.116476e-16  3.116198e-16
# SUCOAS              1.790385e-08  1.790225e-08  1.790066e-08  1.789906e-08
# SUCD1m              6.872012e-13  6.871399e-13  6.870786e-13  6.870174e-13
# FUMm                3.576514e-16  3.576195e-16  3.575876e-16  3.575558e-16
# MDHm                3.104696e-16  3.104419e-16  3.104142e-16  3.103866e-16
# G6PDH2r             9.995928e-01  9.995928e-01  9.995928e-01  9.995928e-01
# PGLh                9.999954e-01  9.999954e-01  9.999954e-01  9.999954e-01
# PGDHh               6.525036e-01  6.525036e-01  6.525036e-01  6.525036e-01
# RPEh                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# RPI                 0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT1                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TALA                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# TKT2                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                            13710
# BFBPh               0.000000e+00
# FBAF                1.484722e+00
# TPI                 6.735248e-01
# G6PIh               6.324479e-03
# PGKm                1.263282e+02
# PGM                 1.257715e+02
# ENOf                7.950961e-03
# PYKf                7.950938e-03
# PDHm                7.950745e-03
# CS                  5.637829e-11
# ACONITATEHYDR__RXN  1.317958e-40
# ICDHxm              0.000000e+00
# ISOCIT__CLEAV__RXN  3.296825e-48
# MALSp               7.955224e-33
# OXGDC               8.892383e-20
# AKGDm               3.115921e-16
# SUCOAS              1.789746e-08
# SUCD1m              6.869561e-13
# FUMm                3.575239e-16
# MDHm                3.103589e-16
# G6PDH2r             9.995928e-01
# PGLh                9.999954e-01
# PGDHh               6.525036e-01
# RPEh                0.000000e+00
# RPI                 0.000000e+00
# TKT1                0.000000e+00
# TALA                0.000000e+00
# TKT2                0.000000e+00
#
# [28 rows x 13711 columns]
# $FrameId
# PFKh                 -3.510000e-06
# BFBPh                 0.000000e+00
# FBAF                 -8.139533e-01
# TPI                   8.139534e-01
# G6PIh                 1.583341e+02
# PGKm                 -1.263971e+02
# PGM                  -1.258383e+02
# ENOf                  1.258378e+02
# PYKf                  1.258378e+02
# PDHm                  1.258364e+02
# CS                    8.078897e-09
# ACONITATEHYDR__RXN    0.000000e+00
# ICDHxm                0.000000e+00
# ISOCIT__CLEAV__RXN    1.253522e-40
# MALSp                 3.996015e-24
# OXGDC                -1.800000e-27
# AKGDm                 4.719265e-08
# SUCOAS               -1.182120e-11
# SUCD1m               -3.146390e-16
# FUMm                 -3.113807e-16
# MDHm                 -3.113807e-16
# G6PDH2r               0.000000e+00
# PGLh                  0.000000e+00
# PGDHh                 0.000000e+00
# RPEh                  0.000000e+00
# RPI                   0.000000e+00
# dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-10e961d14bbb> in <module>()
#      14 display(net_likelihoods)
#      15
# ---> 16 net_likelihoods.columns = [str(c) for c in net_likelihoods.columns]
#      17 net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_net_likelihood.tab', sep='\t')
#      18
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
net_likelihoods.index.name = '$FrameId'
display(net_likelihoods)

net_likelihoods.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_likel.tab',sep='\t')
ode_likelihoods_steadystate.to_csv('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_lklhd_net_stead.tab', sep='\t')
# Out:
# $FrameId
# PFKh                 -3.510000e-06
# BFBPh                 0.000000e+00
# FBAF                 -8.139533e-01
# TPI                   8.139534e-01
# G6PIh                 1.583341e+02
# PGKm                 -1.263971e+02
# PGM                  -1.258383e+02
# ENOf                  1.258378e+02
# PYKf                  1.258378e+02
# PDHm                  1.258364e+02
# CS                    8.078897e-09
# ACONITATEHYDR__RXN    0.000000e+00
# ICDHxm                0.000000e+00
# ISOCIT__CLEAV__RXN    1.253522e-40
# MALSp                 3.996015e-24
# OXGDC                -1.800000e-27
# AKGDm                 4.719265e-08
# SUCOAS               -1.182120e-11
# SUCD1m               -3.146390e-16
# FUMm                 -3.113807e-16
# MDHm                 -3.113807e-16
# G6PDH2r               0.000000e+00
# PGLh                  0.000000e+00
# PGDHh                 0.000000e+00
# RPEh                  0.000000e+00
# RPI                   0.000000e+00
# dtype: float64

# %% [markdown]
# ## Analyze Metabolite Levels from Deterministic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
ode_metabolites = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.ode_concs',header=0,index_col=0)
column_names = [x.split(":")[0] for x in ode_metabolites.columns]
ode_metabolites.columns = column_names

plt.figure();ode_metabolites.plot(legend=True,logy=True,figsize=(9, 9))
plt.legend(bbox_to_anchor=(1.34, 0.75),bbox_transform=plt.gcf().transFigure)

# %%
ode_metabolites.iloc[-30:].mean()
#ode_metabolites['CO2']
# Out:
# 2-OXOGLUTARATE                       0.000000e+00
# 2-PHOSPHO-D-GLYCERATE                9.931909e+00
# 3-PHOSPHO-D-GLYCERATE                1.348982e+04
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      1.095587e+06
# 6-PHOSPHO_D-GLUCONO-1,5-LACTONE      1.912196e-04
# ACETYL-COA                           1.409010e+06
# ADP                                  5.600000e-04
# ALPHA-D-RIBOSE_5-PHOSPHATE           1.000000e-05
# AN_ELECTRON-TRANSFER_QUINOL          1.000000e-03
# AN_ELECTRON-TRANSFER_QUINONE         1.000000e-03
# ATP                                  9.600000e-03
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    1.469576e-02
# CIS-ACONITATE                        0.000000e+00
# CITRATE                              4.464114e-04
# CO2                                  1.000000e-04
# COA                                  1.400000e-03
# D-ERYTHROSE_4-PHOSPHATE              1.000000e-05
# D-GLUCONATE_6-PHOSPHATE              3.717260e-03
# D-GLUCOPYRANOSE_6-PHOSPHATE          1.000000e-03
# D-GLYCERALDEHYDE_3-PHOSPHATE         1.000000e-03
# D-RIBULOSE_5-PHOSPHATE               1.232929e-09
# D-THREO-ISOCITRATE                   0.000000e+00
# D-XYLULOSE_5-PHOSPHATE               2.320598e-06
# FRUCTOSE_1,6-BISPHOSPHATE            1.577819e+04
# FUMARATE                             0.000000e+00
# GLYCERONE_PHOSPHATE                  1.408668e-03
# GLYOXYLATE                           0.000000e+00
# MALATE                               0.000000e+00
# NAD+                                 2.600000e-03
# NADH                                 8.300000e-05
# NADP+                                2.100000e-06
# NADPH                                1.200000e-04
# ORTHOPHOSPHATE                       2.000000e-02
# OXALOACETATE                         0.000000e+00
# PHOSPHOENOLPYRUVATE                  3.128098e-01
# PYRUVATE                             1.805004e+01
# SEDOHEPTULOSE_7-PHOSPHATE            1.000000e-05
# SUCCINATE                            0.000000e+00
# SUCCINATE_SEMIALDEHYDE               0.000000e+00
# SUCCINYL-COA                         0.000000e+00
# dtype: float64

# %% [markdown]
# ## Likelihoods from Stochastic Simulation
# *The average values aren't correct because they don't consider how much relative time was spent in each configuration*

# %%
# Read boltzmann stochastic reaction likelihoods
from IPython.display import display
fwd_columns = np.arange(3,20,2)
rev_columns = np.arange(4,20,2)
stoch_fwd_likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.lklhd',header=1, usecols=fwd_columns,quoting=2)
stoch_rev_likelihoods = pd.read_table('PPP_Gly_TCA_A-COA-Bys1_rxns_mod.lklhd',header=1, usecols=rev_columns,quoting=2)

column_names = [x.split("f_")[-1] for x in stoch_fwd_likelihoods.columns]
stoch_fwd_likelihoods.columns = column_names
column_names = [x.split("r_")[-1] for x in stoch_rev_likelihoods.columns]
stoch_rev_likelihoods.columns = column_names

plt.figure();
stoch_fwd_likelihoods[''].plot(legend=True,logy=False,logx=True,figsize=(12, 12))
plt.yscale('symlog')
#plt.plot(stoch_likelihoods,legend=True)
# plt.plot(stoch_likelihoods,legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.02, 0.9),bbox_transform=plt.gcf().transFigure)

display(stoch_fwd_likelihoods.iloc[-10000:-1].mean() - stoch_rev_likelihoods.iloc[-10000:-1].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-6e035bcb304d> in <module>()
#      12
#      13 plt.figure();
# ---> 14 stoch_fwd_likelihoods[''].plot(legend=True,logy=False,logx=True,figsize=(12, 12))
#      15 plt.yscale('symlog')
#      16 #plt.plot(stoch_likelihoods,legend=True)
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/kuma889/.pyenv/versions/anaconda2-4.3.1/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''

# %% [markdown]
# ## Read in Flux Values from Stochastic Simulation

# %%
#columns = ["Reaction","Description","Flux","Net Flux"]
columns = [0, 3]
skip = np.arange(0,56,2)
stoch_flux = pd.read_table('central_metabolism_dg0_rxns_GLy.view', sep='\t',index_col=[0], header=None, 
                           usecols=columns,quoting=2,skiprows = skip)
stoch_flux.columns=["Net Flux"]
stoch_flux['Rxn Probability'] = stoch_flux['Net Flux']/np.sum(abs(stoch_flux['Net Flux'].values))
stoch_flux
# Out:
#                                Net Flux  Rxn Probability
# 0
# PGLUCISOM__45__RXN                519.0         0.052589
# _6PFRUCTPHOS__45__RXN            1630.0         0.165164
# F16BDEPHOS__45__RXN              1098.0         0.111257
# F16ALDOLASE__45__RXN              534.0         0.054109
# TRIOSEPISOMERIZATION__45__RXN    -559.0        -0.056642
# GAPOXNPHOSPHN__45__RXN           1095.0         0.110953
# PHOSGLYPHOS__45__RXN            -1055.0        -0.106900
# RXN__45__15513                  -1132.0        -0.114703
# _2PGADEHYDRAT__45__RXN           1138.0         0.115311
# PEPDEPHOS__45__RXN               1109.0         0.112372

# %% [markdown]
# ## Analyze Metabolite Levels from Stochastic Simulation

# %%
# Read boltzmann stochastic reaction likelihoods
columns = np.arange(1,57,1)
stoch_metabolites = pd.read_table('central_metabolism_dg0_rxns_GLy.concs',header=0,index_col=0)

plt.figure();stoch_metabolites.plot(legend=True,logy=True,figsize=(12, 12))
plt.legend(bbox_to_anchor=(1.3, 0.92),bbox_transform=plt.gcf().transFigure)

# %%
stoch_metabolites.iloc[-100:,:].mean()
# Out:
# 2-PHOSPHO-D-GLYCERATE                2.498400e-06
# 3-PHOSPHO-D-GLYCERATE                2.290741e-04
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      1.249031e-03
# ADP                                  5.600000e-04
# ATP                                  9.600001e-03
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    1.300263e-04
# D-GLUCOPYRANOSE_6-PHOSPHATE          9.999993e-04
# D-GLYCERALDEHYDE_3-PHOSPHATE         3.020318e-07
# FRUCTOSE_1,6-BISPHOSPHATE            6.113318e-02
# GLYCERONE_PHOSPHATE                  2.731869e-06
# NAD+                                 2.600001e-03
# NADH                                 8.299937e-05
# ORTHOPHOSPHATE                       6.891153e-09
# PHOSPHOENOLPYRUVATE                  1.206948e-06
# PYRUVATE                             9.999993e-04
# dtype: float64

# %% [markdown]
# ## Compare ODE and Stochastic Metabolite Concentrations

# %%
stoch_metabolites.iloc[-100:,:].mean()/ode_metabolites.iloc[-1:,:].mean()
# Out:
# 2-PHOSPHO-D-GLYCERATE                0.998390
# 3-PHOSPHO-D-GLYCERATE                0.999432
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE      1.000053
# ADP                                  1.000000
# ATP                                  1.000000
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE    0.999825
# D-GLUCOPYRANOSE_6-PHOSPHATE          0.999999
# D-GLYCERALDEHYDE_3-PHOSPHATE         1.009860
# FRUCTOSE_1,6-BISPHOSPHATE            1.000000
# GLYCERONE_PHOSPHATE                  0.985530
# NAD+                                 1.000000
# NADH                                 0.999992
# ORTHOPHOSPHATE                       1.693554
# PHOSPHOENOLPYRUVATE                  1.033449
# PYRUVATE                             0.999999
# dtype: float64

# %% [markdown]
# ## Display Pathway Predictions

# %%
from escher import Builder

reaction_data = (stoch_flux['Net Flux'].to_dict())
#reaction_data = (ode_likelihoods_timeseries.iloc[-1]).to_dict()
#for x in reaction_data.keys():
#  y = x.split("f_")[-1]
#  reaction_data[y] = reaction_data.pop(x)
b = Builder(map_name="e_coli_core.Core metabolism",reaction_data=reaction_data)
b.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ejpivulojx"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ejpivulojx"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"RXN0__45__1132": 4.619808448510388e+18, "_3PGAREARR__45__RXN": 4.619808448510388e+18, "RXN__45__12959": 0.0, "PLASTOQUINOL__45____45__PLASTOCYANIN__45__REDUCTASE__45__RXN": 4.619808448510388e+18, "ISOCITRATE__45__DEHYDROGENASE__45__NAD__43____45__RXN": 4.619808448510388e+18, "RXN__45__9952": 4.619808448510388e+18, "RXN0__45__1134": 4.619808448510388e+18, "ACONITATEDEHYDR__45__RXN": 4.619808448510388e+18, "TRANSALDOL__45__RXN": 4.619808448510388e+18, "RXN0__45__1133": 4.619808448510388e+18, "RXN__45__1381": 0.0, "F16BDEPHOS__45__RXN": 0.0, "RXN__45__1641": 0.0, "MALATE__45__DEH__45__RXN": 4.619808448510388e+18, "GAPOXNPHOSPHN__45__RXN": 4.619808448510388e+18, "SEDOHEPTULOSE__45__BISPHOSPHATASE__45__RXN": 0.0, "RXN__45__1623": 0.0, "SEDOBISALDOL__45__RXN": 0.0, "_1TRANSKETO__45__RXN": 0.0, "RXN__45__15513": 4.619808448510388e+18, "ACONITATEHYDR__45__RXN": 4.619808448510388e+18, "_6PGLUCONOLACT__45__RXN": 4.619808448510388e+18, "_1__46__1__46__1__46__8__45__RXN": -4.62081378304968e+18, "_2PGADEHYDRAT__45__RXN": 4.619808448510388e+18, "RXN__45__15479": 4.619808448510388e+18, "PHOSPHORIBULOKINASE__45__RXN": 0.0, "RIB5PISOM__45__RXN": 0.0, "_1__46__2__46__1__46__13__45__RXN": 0.0, "DIACYLGLYCEROL__45__O__45__ACYLTRANSFERASE__45__RXN": 0.0, "TRIOSEPISOMERIZATION__45__RXN": 0.0, "F16ALDOLASE__45__RXN": 0.0, "PSII__45__RXN": 4.619808448510388e+18, "_2TRANSKETO__45__RXN": 0.0, "FUMHYDR__45__RXN": 4.619808448510388e+18, "PEPSYNTH__45__RXN": -4.619808448510388e+18, "PEPDEPHOS__45__RXN": 4.619808448510388e+18, "RXN__45__15745": 0.0, "PHOSGLYPHOS__45__RXN": 0.0, "RIBULP3EPIM__45__RXN": 0.0, "_6PFRUCTPHOS__45__RXN": 4.619808448510388e+18, "PGLUCISOM__45__RXN": 4.619808448510388e+18, "RXN__45__14971": 4.619808448510388e+18, "CITSYN__45__RXN": 4.619808448510388e+18, "PHOSPHATIDATE__45__PHOSPHATASE__45__RXN": 0.0, "_2OXOGLUTARATEDEH__45__RXN": 4.619808448510388e+18, "RIBULOSE__45__BISPHOSPHATE__45__CARBOXYLASE__45__RXN": 0.0, "RXN__45__12383": 0.0, "GLU6PDEHYDROG__45__RXN": 4.619808448510388e+18, "SUCCCOASYN__45__RXN": 4.619808448510388e+18, "_1__46__18__46__1__46__2__45__RXN": 4.619808448510388e+18}, "enable_editing": false, "gene_data": null, "metabolite_data": null, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "e_coli_core.Core metabolism", "map_id": "0df3827fde8464e80f455a773a52c274", "map_description": "E. coli core metabolic network\\nLast Modified Fri Dec 05 2014 16:39:44 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1577514": {"name": "Formate transport in via proton symport", "bigg_id": "FORt2", "segments": {"11": {"to_node_id": "1577044", "from_node_id": "1576666", "b2": {"y": 4749.209372712298, "x": 1360.0}, "b1": {"y": 4827.353507999329, "x": 1360.0}}, "10": {"to_node_id": "1577046", "from_node_id": "1577045", "b2": null, "b1": null}, "13": {"to_node_id": "1576590", "from_node_id": "1577046", "b2": {"y": 4275.94781629675, "x": 1360.0}, "b1": {"y": 4411.784344889025, "x": 1360.0}}, "12": {"to_node_id": "1577044", "from_node_id": "1576833", "b2": {"y": 4744.773286702694, "x": 1360.0}, "b1": {"y": 4779.244289008981, "x": 1360.0}}, "14": {"to_node_id": "1576811", "from_node_id": "1577046", "b2": {"y": 4422.5658350974745, "x": 1360.0}, "b1": {"y": 4455.769750529243, "x": 1360.0}}, "9": {"to_node_id": "1577045", "from_node_id": "1577044", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "for_e"}, {"coefficient": 1.0, "bigg_id": "h_c"}, {"coefficient": 1.0, "bigg_id": "for_c"}, {"coefficient": -1.0, "bigg_id": "h_e"}], "label_x": 1255.7530517578125, "label_y": 4574.13232421875, "gene_reaction_rule": "b0904 or b2492"}, "1577518": {"name": "Formate transport via diffusion", "bigg_id": "FORti", "segments": {"15": {"to_node_id": "1577047", "from_node_id": "1576590", "b2": {"y": 4263.5, "x": 1460.0}, "b1": {"y": 4145.55, "x": 1460.0}}, "16": {"to_node_id": "1576666", "from_node_id": "1577047", "b2": {"y": 4654.322265625, "x": 1460.0}, "b1": {"y": 4488.7, "x": 1460.0}}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false, "metabolites": [{"coefficient": 1.0, "bigg_id": "for_e"}, {"coefficient": -1.0, "bigg_id": "fo

# %% [markdown]
# ## Power and Fluxes

# %%
# Read boltzmann stochastic reaction likelihoods
ode_metabolites = pd.read_table('central_metabolism_dg0_rxns_GLy.ode_concs',header=0,index_col=0)
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#column_names = [x.split(":")[0] for x in ode_metabolites.columns]
#ode_metabolites.columns = column_names

plt.figure();ode_metabolites.plot(legend=False,logx=True,logy=True,figsize=(10, 10))
#plt.legend(bbox_to_anchor=(1.35, 0.95),bbox_transform=plt.gcf().transFigure)

# %%
#ode_metabolites_steadystate = pd.DataFrame()
ode_metabolites_steadystate = \
  pd.DataFrame(data = ode_metabolites.iloc[-20:,:].mean(axis=0),columns=['Mean'])
ode_metabolites_steadystate['CV'] = \
  pd.DataFrame(data = ode_metabolites.iloc[-20:,:].var(axis=0)/ode_metabolites.iloc[-20:,:].mean(axis=0),columns=['ODE'])
ode_metabolites_steadystate['Ratio'] = \
  pd.DataFrame(data =(ode_metabolites.iloc[-1]/ode_metabolites.iloc[0]))


ode_metabolites_steadystate

#ode_metabolites.iloc[-1,:]
# Out:
#                                            Mean            CV         Ratio
# 2-PHOSPHO-D-GLYCERATE              2.502433e-06  4.748010e-18  1.067754e-03
# 3-PHOSPHO-D-GLYCERATE              2.292048e-04  1.152153e-15  5.479970e+00
# 3-PHOSPHO-D-GLYCEROYL_PHOSPHATE    1.248968e-03  1.415906e-14  4.924799e-01
# ADP                                5.600000e-04  2.209576e-35  1.000000e+00
# ATP                                9.600000e-03  0.000000e+00  1.000000e+00
# BETA-D-FRUCTOFURANOSE_6-PHOSPHATE  1.300492e-04  2.489746e-15  1.390426e-01
# D-GLUCOPYRANOSE_6-PHOSPHATE        1.000000e-03  1.979780e-34  1.000000e+00
# D-GLYCERALDEHYDE_3-PHOSPHATE       2.990830e-07  3.220370e-19  2.202675e+04
# FRUCTOSE_1,6-BISPHOSPHATE          6.113382e-02  4.790401e-12  5.741915e+01
# GLYCERONE_PHOSPHATE                2.771985e-06  5.825200e-18  9.635677e-01
# NAD+                               2.600000e-03  3.045815e-34  1.000000e+00
# NADH                               8.300000e-05  9.317489e-36  1.000000e+00
# ORTHOPHOSPHATE                     4.069059e-09  4.675787e-20  2.041125e-07
# PHOSPHOENOLPYRUVATE                1.167885e-06  6.399334e-19  1.167887e-03
# PYRUVATE                           1.000000e-03  1.979780e-34  1.000000e+00

# %%
S = pd.read_table('central_metabolism_dg0_rxns_GLy.mat',header=0, index_col = 0, quoting=2)
R = (S<0)
P = S>0
del R['forward reaction']
del P['forward reaction']
del S['forward reaction']
#S['H2O:CYTOSOL'] =0
#S['H2O:GLYOXYSOME'] =0
#S['H2O:MITOCHONDRIA'] =0

volume_coeff = S.sum(axis=1)

R = R.astype(np.float64)
P = P.astype(np.float64)

steadyState_counts = ode_metabolites_steadystate['Mean']*Concentration2Count

reactant_counts = R.multiply(steadyState_counts,axis=1)
reactant_concs =  R.multiply(ode_metabolites_steadystate['Mean'])
product_counts = P.multiply(steadyState_counts,axis=1)
product_concs = P.multiply(ode_metabolites_steadystate['Mean'])

product_counts_incremented = product_counts + P.multiply(1)
product_concs_incremented = product_concs + P.multiply(concentration_increment)
product_counts = product_counts #+ P.multiply(1)
product_concs = product_concs #+ P.multiply(concentration_increment)

# Take the product of counts of all reactants for a reaction
reactant_counts_rxns = (reactant_counts[reactant_counts != 0].T).product()
reactant_concs_rxns = (reactant_concs[reactant_concs != 0].T).product()

# Take the product of counts of all products for a reaction
product_counts_rxns = (product_counts[product_counts != 0].T).product()
product_concs_rxns = (product_concs[product_concs != 0].T).product()
product_counts_incremented_rxns = (product_counts_incremented[product_counts_incremented != 0].T).product()
product_concs_incremented_rxns = (product_concs_incremented[product_concs_incremented != 0].T).product()
#denominator = reactant_counts_rxns.multiply(1-ode_likelihoods_steadystate['Reverse'])

K_eq = pd.read_table('central_metabolism_dg0_rxns_GLy.dg0ke',header=0, index_col = 0, quoting=2)

result = pd.DataFrame()
result['Boltzmann Ke'] = K_eq['Ke']
# Notice that Computed L_fwd uses incremented product counts. That is so we can compare to Boltzmann values
# when calculating the activities. That is, these need to use the same formula.
result['Computed L_fwd'] = result['Boltzmann Ke'].multiply(reactant_counts_rxns.divide(product_counts_incremented_rxns))
display(result)

idx = np.abs(ode_likelihoods_steadystate['For-Rev']) > 0
DeltaG = "$\Delta G$"
ode_likelihoods_steadystate[DeltaG] = np.nan
ode_likelihoods_steadystate['Power'] = np.nan
ode_likelihoods_steadystate[DeltaG][idx] = -RT*np.log(result['Computed L_fwd'][idx])
ode_likelihoods_steadystate['Power'][idx] = ode_likelihoods_steadystate['For-Rev'][idx]*np.log(result['Computed L_fwd'][idx])
display(ode_likelihoods_steadystate)
# Out:
#                                 Boltzmann Ke  Computed L_fwd
# Rxn_title
# PGLUCISOM__45__RXN                  0.573086        4.406634
# _6PFRUCTPHOS__45__RXN             346.014900       12.618357
# F16BDEPHOS__45__RXN                 0.061978        8.443598
# F16ALDOLASE__45__RXN                0.036199        4.405372
# TRIOSEPISOMERIZATION__45__RXN       2.092269        0.225610
# GAPOXNPHOSPHN__45__RXN            459.328500        8.442958
# PHOSGLYPHOS__45__RXN                0.037496        0.117960
# RXN__45__15513                     10.797310        0.117883
# _2PGADEHYDRAT__45__RXN              3.961900        8.477133
# PEPDEPHOS__45__RXN             124433.300000        8.477203
#                                  Forward   Reverse    For-Rev  \
# $FrameId
# PGLUCISOM__45__RXN              4.406635  0.226927   4.179708
# _6PFRUCTPHOS__45__RXN          12.618359  0.079248  12.539111
# F16BDEPHOS__45__RXN             8.443525  0.084109   8.359416
# F16ALDOLASE__45__RXN            4.405317  0.225610   4.179707
# TRIOSEPISOMERIZATION__45__RXN   0.225610  4.405316  -4.179706
# GAPOXNPHOSPHN__45__RXN          8.443060  0.083648   8.359412
# PHOSGLYPHOS__45__RXN            0.117960  8.477372  -8.359413
# RXN__45__15513                  0.117883  8.477295  -8.359412
# _2PGADEHYDRAT__45__RXN          8.477131  0.117719   8.359412
# PEPDEPHOS__45__RXN              8.477208  0.117795   8.359412
#
#                                Rxn Probabilities  $\Delta G$      Power
# $FrameId
# PGLUCISOM__45__RXN                      0.055556   -3.676568   6.198972
# _6PFRUCTPHOS__45__RXN                   0.166667   -6.284532  31.788559
# F16BDEPHOS__45__RXN                     0.111111   -5.288626  17.834049
# F16ALDOLASE__45__RXN                    0.055556   -3.675857   6.197773
# TRIOSEPISOMERIZATION__45__RXN          -0.055556    3.691037   6.223365
# GAPOXNPHOSPHN__45__RXN                  0.111111   -5.288438  17.833406
# PHOSGLYPHOS__45__RXN                   -0.111111    5.298551  17.867511
# RXN__45__15513                         -0.111111    5.300163  17.872946
# _2PGADEHYDRAT__45__RXN                  0.111111   -5.298452  17.867176
# PEPDEPHOS__45__RXN                      0.111111   -5.298473  17.867245

# %% [markdown]
# # Boltzmann to sbml file for biocyc

# %%
import pandas as pd
import numpy as np
import re, os
def to_chr(  matchobj ):
        return chr(int(matchobj.group(1)))
def to_ord( matchobj ):
        return '__{}__'.format(ord(matchobj.group(0)))    
def munge( sbmlid ):
    alphaRE = re.compile(r'[^A-Za-z_]')
    m = alphaRE.match(sbmlid[0])
    if m:
        sbmlid = '_{}'.format(sbmlid)
    alphanumRE = re.compile(r'[^A-Za-z0-9_]')
    sbmlid = alphanumRE.sub(to_ord, sbmlid)
    return sbmlid
def unmunge( sbmlid ):
    ordRE = re.compile('__([0-9]+)__')
    if '_' == sbmlid[0] and '_' != sbmlid[1]:
        sbmlid = sbmlid[1:]
    return ordRE.sub( to_chr, sbmlid)    
def unmunge_model( model ):     
    for met in model.metabolites:
        met.id = unmunge(met.id)
    for rxn in model.reactions:
        rxn.id = unmunge(rxn.id)
    return model

# %%
concs = pd.read_table('central_metabolism_dg0_rxns_GLy.ode_concs',index_col=0)#.apply(np.log)
log_concs = concs.apply(np.log).T
log_concs.index
mets = {'2-PHOSPHO-D-GLYCERATE':'2-PG', 
        '3-PHOSPHO-D-GLYCERATE':'G3P',
        '3-PHOSPHO-D-GLYCEROYL_PHOSPHATE':'DPG', 
        'ADP':'ADP', 
        'AMP':'AMP', 
        'ATP':'ATP',
       'BETA-D-FRUCTOFURANOSE_6-PHOSPHATE':'FRUCTOSE-6P', 
        'D-GLUCOPYRANOSE_6-PHOSPHATE':'D-glucopyranose-6-phosphate',
       'D-GLYCERALDEHYDE_3-PHOSPHATE':'GAP', 
        'FRUCTOSE_1,6-BISPHOSPHATE':'FRUCTOSE-16-DIPHOSPHATE',
       'GLYCERONE_PHOSPHATE':'DIHYDROXY-ACETONE-PHOSPHATE', 
        'H+':'PROTON', 
        'NAD+':'NAD', 
        'NADH':'NADH', 
        'ORTHOPHOSPHATE':'Pi',
       'PHOSPHOENOLPYRUVATE':'PHOSPHO-ENOL-PYRUVATE', 
        'PYRUVATE':'PYRUVATE'}

log_concs.index = [mets[m] for m in log_concs.index]
log_concs.index.name='$Metabolite'

#log_concs[['0','10000']].to_csv('central_metabolism_dg0_rxns_GLy.log_concs.tab',sep='\t')
#log_concs
